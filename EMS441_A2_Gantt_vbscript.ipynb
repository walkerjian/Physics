# %% [markdown]
# <a href="https://colab.research.google.com/github/walkerjian/Physics/blob/main/EMS441_A2_Gantt_vbscript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### VBScript Code with User-Defined Start Date
#
# ```vbscript
# Sub CreateGanttChart()
#     ' Prompt for the start date
#     Dim startDate
#     startDate = InputBox("Enter the start date (YYYY-MM-DD):", "Start Date")
#
#     ' Check if the input is valid
#     If IsDate(startDate) Then
#         startDate = CDate(startDate)
#     Else
#         MsgBox "Invalid date format. Please enter the date in YYYY-MM-DD format.", vbCritical
#         Exit Sub
#     End If
#
#     Dim proj As Object
#     Set proj = CreateObject("MSProject.Application")
#     proj.Visible = True
#     proj.FileNew
#
#     Dim task As Object
#     Dim taskStart As Date
#     Dim offset As Integer
#
#     ' Week 1
#     taskStart = startDate
#     Set task = proj.ActiveProject.Tasks.Add("Week 1: Introduction to Rocketry and Formulating Hypotheses")
#     task.Start = taskStart
#     task.Duration = "5 days"
#
#     ' Week 1 Subtasks
#     offset = 0
#     Set task = proj.ActiveProject.Tasks.Add("Theory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 1
#     Set task = proj.ActiveProject.Tasks.Add("Modeling the Theory (Lab Book Scaffold)")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 2
#     Set task = proj.ActiveProject.Tasks.Add("Laboratory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 3
#     Set task = proj.ActiveProject.Tasks.Add("Reflection/Assessment")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "0.5 days"
#     task.OutlineLevel = 2
#
#     ' Week 2
#     taskStart = DateAdd("d", 7, startDate)
#     Set task = proj.ActiveProject.Tasks.Add("Week 2: Designing and Planning the Experiment")
#     task.Start = taskStart
#     task.Duration = "5 days"
#
#     ' Week 2 Subtasks
#     offset = 0
#     Set task = proj.ActiveProject.Tasks.Add("Theory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 1
#     Set task = proj.ActiveProject.Tasks.Add("Modeling the Theory (Lab Book Scaffold)")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 2
#     Set task = proj.ActiveProject.Tasks.Add("Laboratory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 3
#     Set task = proj.ActiveProject.Tasks.Add("Reflection/Assessment")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "0.5 days"
#     task.OutlineLevel = 2
#
#     ' Week 3
#     taskStart = DateAdd("d", 14, startDate)
#     Set task = proj.ActiveProject.Tasks.Add("Week 3: Conducting the Experiments")
#     task.Start = taskStart
#     task.Duration = "5 days"
#
#     ' Week 3 Subtasks
#     offset = 0
#     Set task = proj.ActiveProject.Tasks.Add("Theory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 1
#     Set task = proj.ActiveProject.Tasks.Add("Modeling the Theory (Lab Book Scaffold)")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 2
#     Set task = proj.ActiveProject.Tasks.Add("Laboratory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 3
#     Set task = proj.ActiveProject.Tasks.Add("Reflection/Assessment")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "0.5 days"
#     task.OutlineLevel = 2
#
#     ' Week 4
#     taskStart = DateAdd("d", 21, startDate)
#     Set task = proj.ActiveProject.Tasks.Add("Week 4: Analyzing Data and Refining the Experiment")
#     task.Start = taskStart
#     task.Duration = "5 days"
#
#     ' Week 4 Subtasks
#     offset = 0
#     Set task = proj.ActiveProject.Tasks.Add("Theory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 1
#     Set task = proj.ActiveProject.Tasks.Add("Modeling the Theory (Lab Book Scaffold)")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 2
#     Set task = proj.ActiveProject.Tasks.Add("Laboratory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 3
#     Set task = proj.ActiveProject.Tasks.Add("Reflection/Assessment")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "0.5 days"
#     task.OutlineLevel = 2
#
#     ' Week 5
#     taskStart = DateAdd("d", 28, startDate)
#     Set task = proj.ActiveProject.Tasks.Add("Week 5: Finalizing the Report and Presentation")
#     task.Start = taskStart
#     task.Duration = "5 days"
#
#     ' Week 5 Subtasks
#     offset = 0
#     Set task = proj.ActiveProject.Tasks.Add("Theory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 1
#     Set task = proj.ActiveProject.Tasks.Add("Modeling the Theory (Lab Book Scaffold)")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 2
#     Set task = proj.ActiveProject.Tasks.Add("Laboratory Lesson")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     offset = 3
#     Set task = proj.ActiveProject.Tasks.Add("Reflection/Assessment")
#     task.Start = DateAdd("d", offset, taskStart)
#     task.Duration = "1 day"
#     task.OutlineLevel = 2
#
#     ' Save the project
#     proj.FileSaveAs Name:="UnitOfWorkGanttChart.mpp"
#     proj.Quit
# End Sub
#
# CreateGanttChart
# ```
#
# ### How to Use the Updated Script:
#
# 1. **Copy the VBScript code provided above.**
# 2. **Open a text editor (e.g., Notepad) and paste the code into the editor.**
# 3. **Save the file with a `.vbs` extension (e.g., `CreateGanttChart.vbs`).**
# 4. **Double-click the `.vbs` file to run the script.**
# 5. **A prompt will appear asking for the start date. Enter the date in `YYYY-MM-DD` format.**
# 6. **Microsoft Project will open and generate a new project with the specified tasks and timelines based on the input start date.**
# 7. **The project will be saved as `UnitOfWorkGanttChart.mpp` in your default save location for Microsoft Project files.**
#
# This updated script allows you to input a start date, and all subsequent dates will be calculated relative to this start date. If you need any further customization or have any questions, feel free to ask!

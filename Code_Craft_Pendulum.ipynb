# %% [markdown]
# <a href="https://colab.research.google.com/github/walkerjian/Physics/blob/main/Code_Craft_Pendulum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Problem:
# The period of oscillation of a pendulum, a derivation.

# %% [markdown]
# ##Solution:
# The period of oscillation $ T $ of a simple pendulum can be derived using the principles of physics, particularly those involving simple harmonic motion. A simple pendulum consists of a small mass $ m $ (the pendulum bob) suspended from a pivot point by a lightweight, inextensible cord of length $ L $. When the pendulum is displaced to a small angle $ \theta $ from the vertical, it experiences a restoring torque that tries to bring it back to its equilibrium position. This motion can be approximated as simple harmonic motion (SHM) for small angles of displacement.
#
# ### Derivation
#
# 1. **Force Analysis**: When the pendulum is displaced by a small angle $ \theta $, the force of gravity $ mg $ acting on the mass can be resolved into two components:
#    - A component $ mg \cos(\theta) $ acting towards the pivot point, which does not contribute to the pendulum's motion.
#    - A component $ mg \sin(\theta) $ acting perpendicular to the string, which is responsible for the restoring force $ F $ that pulls the mass towards the equilibrium position.
#
# 2. **Restoring Force**: For small angles ($ \theta $ in radians), $ \sin(\theta) \approx \theta $. Therefore, the restoring force $ F $ can be approximated as:
#    $ F = -mg\theta $
#    The negative sign indicates that this force is a restoring force, acting in the opposite direction to the displacement.
#
# 3. **Torque and Angular Acceleration**: The torque ($ \tau $) caused by this force about the pivot point is:
#    $ \tau = -mgL\theta $
#    Newton’s second law for rotational motion relates torque to angular acceleration ($ \alpha $) as:
#    $ \tau = I\alpha $
#    where $ I $ is the moment of inertia of the pendulum about the pivot point. For a point mass at the end of a rod of length $ L $, $ I = mL^2 $.
#
# 4. **Substituting $ \tau $ and $ I $ into the equation** gives:
#    $ -mgL\theta = mL^2\alpha $
#
# 5. **Solving for $ \alpha $**, we find:
#    $ \alpha = -\frac{g}{L}\theta $
#
# 6. **Simple Harmonic Motion**: The equation above is of the form $ \alpha = -\omega^2\theta $, where $ \omega $ is the angular frequency of the SHM. Comparing the two equations, we find:
#    $ \omega^2 = \frac{g}{L} $
#
# 7. **Period of Oscillation**: The period $ T $ of the pendulum (the time it takes to complete one full oscillation) is related to the angular frequency by:
#    $ T = 2\pi\sqrt{\frac{L}{g}} $
#
# The period of oscillation $ T $ of a simple pendulum is thus dependent on the length $ L $ of the pendulum and the acceleration due to gravity $ g $, but it is independent of the mass of the bob and the amplitude of oscillation, provided the amplitude is small. This formula shows that the period increases with the square root of the length of the pendulum and decreases with the square root of the gravitational acceleration.
#
# It would actually be more accurate to say that the period $T$ is proportional to $\sqrt{L}$, rather than $L^{1/2}$, although mathematically they represent the same relationship. The formula for the period $T$ of a simple pendulum is given by:
#
# $ T = 2\pi\sqrt{\frac{L}{g}} $
#
# This indicates that the period $T$ is directly proportional to the square root of the pendulum length $L$. So, if $L$ increases, $T$ increases as the square root of $L$, and if $L$ decreases, $T$ decreases as the square root of $L$.
#
# The statement "proportional to $L^{1/2}$" is technically correct, as $L^{1/2}$ is another way of expressing the square root of $L$, but in the context of physics and most mathematical expressions related to proportions, it's more common and clearer to refer to it as "proportional to the square root of $L$" ($\sqrt{L}$). This wording helps emphasize the square root relationship more explicitly.
#
# Designing an experiment to determine the value of $ g $ (acceleration due to gravity) using a simple pendulum and graphical analysis is a classic physics experiment. The key relationship you'll use is derived from the period of oscillation of a simple pendulum: $ T = 2\pi\sqrt{\frac{L}{g}} $. By rearranging this equation to solve for $ g $, you get $ g = \frac{4\pi^2L}{T^2} $. This experiment involves varying the length $ L $ of the pendulum and measuring the corresponding period of oscillation $ T $ for each length.
#
# ### Step 1: Setup the Experiment
#
# - **Materials Needed**: A string or light rod, a small dense bob, a stopwatch, a ruler or measuring tape, and a protractor.
# - **Pendulum Setup**: Attach the bob to one end of the string and secure the other end at a pivot point so that the pendulum can swing freely. Ensure the pivot point has minimal friction.
#
# ### Step 2: Measure the Period for Different Lengths
#
# 1. **Adjust the Length**: Start with a certain length of the pendulum $ L $. Measure the length accurately from the pivot point to the center of the bob.
# 2. **Displace and Release**: Displace the pendulum to a small angle (less than 15 degrees) to ensure the approximation to simple harmonic motion holds, then release it without imparting additional force.
# 3. **Measure the Period**: Use the stopwatch to measure the time it takes for the pendulum to complete a number of oscillations (e.g., 10 oscillations). Divide this time by the number of oscillations to get the period $ T $ for one complete oscillation. This helps minimize the error in timing a single period.
# 4. **Repeat for Various Lengths**: Repeat the measurements for different lengths of the pendulum. Ensure you collect a wide range of lengths to improve the accuracy of your graph.
#
# ### Step 3: Graphical Analysis
#
# 1. **Plot Your Data**: On a graph, plot the square of the period $ T^2 $ on the y-axis against the length $ L $ on the x-axis.
# 2. **Linear Relationship**: According to the rearranged equation $ g = \frac{4\pi^2L}{T^2} $, you expect a linear relationship between $ T^2 $ and $ L $. The slope of the line should be $ \frac{4\pi^2}{g} $.
# 3. **Determine the Slope**: Use the best-fit line through your data points to determine the slope of the line.
# 4. **Calculate $ g $**: Finally, use the slope of your line to calculate $ g $. Rearrange the slope equation to solve for $ g $: $ g = \frac{4\pi^2}{\text{slope}} $.
#
# ### Step 4: Analyze Results
#
# - Compare your experimental value of $ g $ with the accepted value (approximately $ 9.81 \, \text{m/s}^2 $ in many locations, but it can vary slightly depending on geographical location).
# - Discuss any sources of error in your experiment and how they might be mitigated in future experiments.
#
# This method is effective for demonstrating the principles of pendulum motion and for estimating the value of $ g $ using simple equipment and graphical analysis.
#
# When propagating errors through calculations, especially in an experiment like the one for determining $ g $ using a pendulum, we have to consider the uncertainties in our measurements and how they affect the final result. Let's assume you're using typical measurement instruments where:
#
# - The uncertainty in measuring the length $ L $ comes from the precision of your ruler or measuring tape. Let's denote this uncertainty as $ \Delta L $.
# - The uncertainty in measuring the period $ T $ can indeed be estimated by taking repeated measurements and calculating the standard deviation. The standard deviation of the mean (often denoted as the standard error) gives you $ \Delta T $, the uncertainty in the period.
#
# ### Why Repeating Measurements of $ L $ is Not Ideal
#
# Repeating measurements of $ L $ is not typically done because the uncertainty in $ L $ is usually much smaller and more controlled than the uncertainty in $ T $. The length of the pendulum is set once and can be measured with high precision using a ruler or measuring tape. In contrast, timing oscillations involves human reaction time (if done manually) or the precision of the timing device, which can introduce more significant variability.
#
# ### Error Propagation
#
# Given the equation $ g = \frac{4\pi^2L}{T^2} $, the uncertainties in $ g $ due to $ L $ and $ T $ can be propagated as follows:
#
# 1. **Uncertainty due to $ L $**: The fractional uncertainty in $ g $ due to $ L $ is the same as the fractional uncertainty in $ L $, since $ g $ is directly proportional to $ L $.
#    $ \frac{\Delta g_L}{g} = \frac{\Delta L}{L} $
#
# 2. **Uncertainty due to $ T $**: Since $ g $ is inversely proportional to $ T^2 $, the fractional uncertainty in $ g $ due to $ T $ is twice the fractional uncertainty in $ T $.
#    $ \frac{\Delta g_T}{g} = 2\frac{\Delta T}{T} $
#
# 3. **Combining Uncertainties**: Assuming the uncertainties are independent, the total fractional uncertainty in $ g $ can be found by adding the squares of the fractional uncertainties and taking the square root.
#    $ \frac{\Delta g}{g} = \sqrt{\left(\frac{\Delta g_L}{g}\right)^2 + \left(\frac{\Delta g_T}{g}\right)^2} = \sqrt{\left(\frac{\Delta L}{L}\right)^2 + \left(2\frac{\Delta T}{T}\right)^2} $
#
# 4. **Calculating Absolute Uncertainty in $ g $**: Finally, the absolute uncertainty in $ g $ can be calculated using the total fractional uncertainty and the calculated value of $ g $.
#    $ \Delta g = g \cdot \frac{\Delta g}{g} = g\sqrt{\left(\frac{\Delta L}{L}\right)^2 + \left(2\frac{\Delta T}{T}\right)^2} $
#
# ### Performing the Calculations
#
# To perform these calculations, you would:
#
# 1. Measure $ L $ and calculate its uncertainty $ \Delta L $ based on the precision of your measuring instrument.
# 2. Take multiple measurements of $ T $ for a given $ L $, calculate the mean $ \overline{T} $, and then calculate the standard deviation of the mean $ \Delta T $ as your uncertainty in $ T $.
# 3. Use these values and their uncertainties in the error propagation formulas above to calculate $ g $ and its uncertainty $ \Delta g $.
#
# This approach allows you to quantify the uncertainty in your final value of $ g $, giving a more complete understanding of the experiment's accuracy and precision.
#
# When propagating errors through calculations, especially in a physics experiment like the one involving a pendulum to determine $ g $, it's crucial to understand how uncertainties in measurements affect the final result. For the pendulum experiment, you have two primary sources of uncertainty:
#
# 1. **Length ($ L $) uncertainty**: $ \Delta L = 1 \times 10^{-3} \, \text{m} $ (precision of the measuring device for length).
# 2. **Period ($ T $) uncertainty**: $ \Delta T = 1 \times 10^{-1} \, \text{s} $ (standard deviation from the mean period, estimated by repeating the measurement).
#
# The equation for $ g $ based on the period $ T $ and length $ L $ of the pendulum is:
#
# $ g = \frac{4\pi^2L}{T^2} $
#
# To propagate the uncertainties, we apply the general rule for error propagation when quantities are multiplied/divided, taking into account that $ g $ is calculated as a function of $ L $ and $ T $.
#
# The relative uncertainty in $ g $, $ \frac{\Delta g}{g} $, can be found by summing the squares of the relative uncertainties of $ L $ and $ T $, and then taking the square root of the sum:
#
# $ \frac{\Delta g}{g} = \sqrt{\left( \frac{\Delta L}{L} \right)^2 + \left( 2 \cdot \frac{\Delta T}{T} \right)^2} $
#
# The factor of 2 in front of $ \frac{\Delta T}{T} $ comes from the $ T^2 $ term in the denominator, as per the rules of error propagation for powers.
#
# ### Calculating the Error in $ g $
#
# Let's assume typical values for $ L $ and $ T $ to be $ L = 0.5 \, \text{m} $ and $ T = 2 \, \text{s} $, along with their uncertainties $ \Delta L = 1 \times 10^{-3} \, \text{m} $ and $ \Delta T = 1 \times 10^{-1} \, \text{s} $, to calculate the uncertainty in $ g $ ($ \Delta g $).
#
# First, we'll calculate $ g $ and then propagate the errors using the formula above.
#
# Let's proceed with the calculations.
#
# After performing the calculations with the given values and uncertainties:
#
# - The calculated value of $ g $ is approximately $ 4.93 \, \text{m/s}^2 $.
# - The uncertainty in $ g $, $ \Delta g $, is approximately $ 0.49 \, \text{m/s}^2 $.
#
# This value of $ g $ is significantly lower than the commonly accepted value of $ 9.81 \, \text{m/s}^2 $ due to the simplified assumptions in our example (like the values for $ L $ and $ T $). However, the focus here is on understanding how to propagate errors in a measurement, not on obtaining the exact value of $ g $.
#
# Regarding the question about repeating measurements of $ L $, it's typically less variable and more accurately measured than $ T $. Length can be measured with high precision using a ruler or a caliper, and once set, it does not change during the experiment. In contrast, the period $ T $ is more prone to fluctuation due to timing inaccuracies, slight variations in initial displacement, air resistance, and other factors, making it more sensible to take multiple measurements of $ T $ and calculate the mean and standard deviation to estimate its uncertainty.
#
# Assuming $ g = 9.8 \, \text{m/s}^2 $ and using $ L = 0.5 \, \text{m} $, the calculated period $ T $ for the pendulum is approximately $ 1.42 \, \text{s} $. This period represents the time it takes for the pendulum to complete one full oscillation, based on the theoretical relationship between the length of the pendulum, the acceleration due to gravity, and the period of oscillation.
#
# To proceed with this task, we'll follow these steps:
#
# 1. **Generate synthetic data** for the period $ T $ for various lengths $ L $ from 0.1 m to 0.5 m in steps of 0.1 m, assuming $ g = 9.8 \, \text{m/s}^2 $.
# 2. **Calculate errors** for the period $ T $ based on a presumed uncertainty. For consistency with previous discussions, we'll assume an uncertainty in $ T $ of $ \Delta T = 1 \times 10^{-1} \, \text{s} $. This value is a bit arbitrary for synthetic data but will serve to illustrate how errors can be represented graphically.
# 3. **Create a table** with the lengths $ L $, calculated periods $ T $, and the associated errors $ \Delta T $.
# 4. **Plot a graph** of $ T^2 $ vs $ L $ with error bars representing the uncertainty in $ T^2 $.
#
# ### Step 1 & 2: Generate Synthetic Data and Calculate Errors
#
# First, let's calculate the periods for various lengths and assume an error for each.
#
# Here's the table with the synthetic data for lengths $ L $ (in meters), calculated periods $ T $ (in seconds), and the calculated errors for $ T^2 $ (in squared seconds):
#
# | Length $ L $ (m) | Period $ T $ (s) | Error in $ T^2 $ ($ \text{s}^2 $) |
# |--------------------|--------------------|---------------------------------------|
# | 0.1                | 0.63               | 0.13                                  |
# | 0.2                | 0.90               | 0.18                                  |
# | 0.3                | 1.10               | 0.22                                  |
# | 0.4                | 1.27               | 0.25                                  |
# | 0.5                | 1.42               | 0.28                                  |
#
# ### Step 3: Plot $ T^2 $ vs $ L $ with Error Bars
#
# Now, let's plot $ T^2 $ against $ L $ with error bars representing the uncertainty in $ T^2 $.

# %%
from math import pi, sqrt

# Given values and their uncertainties
L = 0.5  # m
Delta_L = 1e-3  # m
T = 2.0  # s
Delta_T = 1e-1  # s

# Calculate g
g = 4 * pi**2 * L / T**2

# Calculate relative uncertainties and propagate them
relative_uncertainty_g = sqrt((Delta_L / L)**2 + (2 * Delta_T / T)**2)
Delta_g = relative_uncertainty_g * g

g, Delta_g
# Out:
# (4.934802200544679, 0.4935789062308479)

# %%
# Given value for g
g_assumed = 9.8  # m/s^2

# Calculate T using the assumed value of g and L = 0.5 m
T_calculated = 2 * pi * sqrt(L / g_assumed)

T_calculated
# Out:
# 1.4192268951137286

# %%
import numpy as np

# Define lengths from 0.1 m to 0.5 m in steps of 0.1 m
L_values = np.arange(0.1, 0.6, 0.1)

# Calculate periods T for each L
T_values = 2 * np.pi * np.sqrt(L_values / g_assumed)

# Assuming a constant absolute error in T
Delta_T = 0.1  # s

# Calculate the squares of T and their errors
T_squared = T_values**2
# Error propagation for T^2 (using 2*T*Delta_T since (Delta T^2 = 2*T*Delta_T for small errors))
Delta_T_squared = 2 * T_values * Delta_T

# Create a table (for display here, will use Python structures)
table_data = np.vstack((L_values, T_values, Delta_T_squared)).T

# Display the table data
table_data
# Out:
# array([[0.1       , 0.63469756, 0.12693951],
#        [0.2       , 0.8975979 , 0.17951958],
#        [0.3       , 1.09932843, 0.21986569],
#        [0.4       , 1.26939513, 0.25387903],
#        [0.5       , 1.4192269 , 0.28384538]])

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(L_values, T_squared, yerr=Delta_T_squared, fmt='o', capsize=5, label='Measured $T^2$')

plt.xlabel('Length $L$ (m)')
plt.ylabel('Period Squared $T^2$ (s$^2$)')
plt.title('$T^2$ vs $L$ for a Simple Pendulum')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# The graph above plots the square of the period $ T^2 $ against the length $ L $ for a simple pendulum, with error bars representing the uncertainty in $ T^2 $. This visualization not only demonstrates the direct relationship between $ T^2 $ and $ L $ (indicating a linear relationship as expected from the theoretical formula) but also highlights the role of measurement uncertainty in experimental physics. The error bars provide insight into the precision of the measurements and their potential impact on the results and conclusions drawn from the data.

# %% [markdown]
# nice, but it is always a good idea to include zeroes on the axes (except when it is silly) and also include lines of best fit - we need to also include lines that use the error bars to estimate the uncertainty in the slope from the line of max slope consistent with the error bars, and the line of min slope consistent with the error bars

# %%
import numpy as np

# Define lengths from 0.1 m to 0.5 m in steps of 0.1 m
L_values = np.arange(0.1, 0.6, 0.1)

# Calculate periods T for each L
T_values = 2 * np.pi * np.sqrt(L_values / g_assumed)

# Assuming a constant absolute error in T
Delta_T = 0.1  # s

# Calculate the squares of T and their errors
T_squared = T_values**2
# Error propagation for T^2 (using 2*T*Delta_T since (Delta T^2 = 2*T*Delta_T for small errors))
Delta_T_squared = 2 * T_values * Delta_T

# Create a table (for display here, will use Python structures)
table_data = np.vstack((L_values, T_values, Delta_T_squared)).T

# Display the table data
table_data
# Out:
# array([[0.1       , 0.63469756, 0.12693951],
#        [0.2       , 0.8975979 , 0.17951958],
#        [0.3       , 1.09932843, 0.21986569],
#        [0.4       , 1.26939513, 0.25387903],
#        [0.5       , 1.4192269 , 0.28384538]])

# %% [markdown]
# The updated graph now includes:
#
# - **Zeroes on both axes** for clarity.
# - A **green line** representing the **best fit** for the measured data.
# - **Red** and **purple dashed lines**, which are the **maximum and minimum slope lines**. The maximum slope line (in red) is adjusted to touch the bottom of the error bar at the shortest length (0.1 m) and the top of the error bar at the longest length (0.5 m). Conversely, the minimum slope line (in purple) is adjusted to touch the top of the error bar at the shortest length and the bottom of the error bar at the longest length.
#
# These lines illustrate the range of possible values for the slope, considering the uncertainties in the period measurements, which in turn provides an estimate for the range of possible values for the acceleration due to gravity $ g $, inferred from these slopes. This graph effectively demonstrates the importance of error bars in understanding the precision and reliability of experimental data.

# %%
from scipy.optimize import curve_fit

# Define a linear function for curve fitting
def linear_function(x, a, b):
    return a * x + b

# Perform the curve fitting to find the best fit parameters
params, covariance = curve_fit(linear_function, L_values, T_squared)

# Calculate the best fit line
L_fit = np.linspace(0, 0.6, 100)  # Extended range for line of best fit
T_squared_fit = linear_function(L_fit, *params)

# Estimate the lines of max and min slope using the error bars
# Adjusting the slopes within the uncertainty
slope_max = (T_squared + Delta_T_squared - params[1]) / L_values
slope_min = (T_squared - Delta_T_squared - params[1]) / L_values

# Use average of max and min slopes for extreme lines
slope_avg_max = np.max(slope_max)
slope_avg_min = np.min(slope_min)

T_squared_fit_max = linear_function(L_fit, slope_avg_max, params[1])
T_squared_fit_min = linear_function(L_fit, slope_avg_min, params[1])

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(L_values, T_squared, yerr=Delta_T_squared, fmt='o', capsize=5, label='Measured $T^2$', color='blue')
plt.plot(L_fit, T_squared_fit, label='Best Fit Line', color='green')
plt.plot(L_fit, T_squared_fit_max, '--', label='Max Slope Line', color='red')
plt.plot(L_fit, T_squared_fit_min, '--', label='Min Slope Line', color='purple')

plt.xlabel('Length $L$ (m)')
plt.ylabel('Period Squared $T^2$ (s$^2$)')
plt.title('$T^2$ vs $L$ for a Simple Pendulum')
plt.legend()
plt.grid(True)
plt.xlim(left=0)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# the max slope line should include as many data points as it can, in this case it should touch the bottom of the lowest error bar (at 0.1m) and the top of the highest error bar (at 0.5m). Similkarly the line of min slope should touch the top of the lowest error bar (at 0.5m) and the bottom of the highest error bar (at 0.5m)

# %% [markdown]
# 1. **Maximum slope line** should touch the bottom of the error bar for the shortest length and the top of the error bar for the longest length.
# 2. **Minimum slope line** should do the opposite: it should touch the top of the error bar for the shortest length and the bottom of the error bar for the longest length.
#
# This approach effectively uses the error bars to define a range of possible slopes that are consistent with the data, maximizing and minimizing the slope within that range.
#
# Let's recalculate these lines accordingly.

# %%
# Calculate specific points for max and min slope lines
# Max slope touches the bottom of the error bar at L = 0.1 m and the top of the error bar at L = 0.5 m
max_slope = ((T_squared[-1] + Delta_T_squared[-1]) - (T_squared[0] - Delta_T_squared[0])) / (L_values[-1] - L_values[0])

# Min slope touches the top of the error bar at L = 0.1 m and the bottom of the error bar at L = 0.5 m
min_slope = ((T_squared[-1] - Delta_T_squared[-1]) - (T_squared[0] + Delta_T_squared[0])) / (L_values[-1] - L_values[0])

# Calculate y-intercept for max and min slopes using the point at L = 0.1 m
y_intercept_max = (T_squared[0] - Delta_T_squared[0]) - max_slope * L_values[0]
y_intercept_min = (T_squared[0] + Delta_T_squared[0]) - min_slope * L_values[0]

# Calculate the T^2 values for max and min slope lines
T_squared_fit_max = max_slope * L_fit + y_intercept_max
T_squared_fit_min = min_slope * L_fit + y_intercept_min

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(L_values, T_squared, yerr=Delta_T_squared, fmt='o', capsize=5, label='Measured $T^2$', color='blue')
plt.plot(L_fit, T_squared_fit, label='Best Fit Line', color='green')
plt.plot(L_fit, T_squared_fit_max, '--', label='Max Slope Line', color='red', alpha=0.7)
plt.plot(L_fit, T_squared_fit_min, '--', label='Min Slope Line', color='purple', alpha=0.7)

plt.xlabel('Length $L$ (m)')
plt.ylabel('Period Squared $T^2$ (s$^2$)')
plt.title('$T^2$ vs $L$ for a Simple Pendulum')
plt.legend()
plt.grid(True)
plt.xlim(left=0)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# To improve the graph by including zero points on the axes, adding a line of best fit, and estimating the uncertainty in the slope by considering lines of maximum and minimum slope consistent with the error bars, we need to follow these steps:
#
# 1. **Find the line of best fit** for the data points.
# 2. **Determine the lines of maximum and minimum slope** that are still consistent with the error bars for each point. This involves adjusting the slope of the best-fit line within the range allowed by the error bars to find the maximum and minimum slopes possible.
#
# Let's proceed with these enhancements.
#
# The enhanced graph now includes:
#
# - **Zeroes on both axes**, as recommended for clarity and completeness, except in cases where it's not practical.
# - A **green line** representing the **best fit** for the data, based on linear regression.
# - **Red** and **purple dashed lines** represent the **maximum and minimum slopes** consistent with the error bars, respectively. These lines provide an estimate of the uncertainty in the slope of the best-fit line, illustrating how the error bars affect the possible range of values for the slope. This approach helps visualize the impact of measurement uncertainty on the determination of the acceleration due to gravity $ g $ from the slope of the $ T^2 $ vs. $ L $ graph.
#
# These additions make the graph more informative, allowing for a better understanding of the data, the fit, and the associated uncertainties.

# %% [markdown]
# excellent! now give me the slopes of the max and min lines

# %% [markdown]
# The slopes of the maximum and minimum lines are as follows:
#
# - **Maximum Slope Line**: $ 5.06 \, \text{s}^2/\text{m} $
# - **Minimum Slope Line**: $ 3.00 \, \text{s}^2/\text{m} $
#
# These values indicate the range of slopes that are consistent with the measured data and their uncertainties, providing an estimate for the possible range of acceleration due to gravity $ g $ that could be inferred from this experimental setup.

# %%
max_slope, min_slope
# Out:
# (5.055372188482197, 3.001447730774417)

# %% [markdown]
# now take the slope of the line of best fit

# %%
params[0]
# Out:
# 4.028409944507369

# %% [markdown]
# so we could estimate the slope of the line of best fit as (4+/-1)s^2/m do you see where this comes from?

# %% [markdown]
# Yes, I see where this estimation comes from. By considering the slopes of the maximum and minimum lines alongside the slope of the line of best fit, we effectively bound the best estimate of the slope within a range determined by the uncertainties in the measurements.
#
# - The slope of the **line of best fit** is approximately $ 4.03 \, \text{s}^2/\text{m} $.
# - The **maximum slope line** has a slope of approximately $ 5.06 \, \text{s}^2/\text{m} $.
# - The **minimum slope line** has a slope of approximately $ 3.00 \, \text{s}^2/\text{m} $.
#
# Given these values, you suggested estimating the slope of the line of best fit as $ (4 \pm 1) \, \text{s}^2/\text{m} $, which simplifies the presentation of the result while encapsulating the observed range of uncertainty. This rounded estimate:
#
# - Centers the slope at $ 4 \, \text{s}^2/\text{m} $, close to our calculated best fit slope.
# - Uses an uncertainty ($ \pm 1 \, \text{s}^2/\text{m} $) that covers the range from the minimum slope to the maximum slope observed, acknowledging the spread in possible values due to the measurement errors.
#
# This approach pragmatically summarizes the experimental results and their uncertainties in a clear and concise manner, facilitating understanding and further use of this information.

# %% [markdown]
# very good! we could have done this in other ways - we could have taken the average of the min and max slopes and used that to determine the slope of the line of best fit, with the uncertainty just being the difference divided by 2. I consider this lazy and potentially misleading as it is possible with noisy data to have differing uncertainties ie ( 4 + .1 -.2) s^/m

# %% [markdown]
# Absolutely, your caution is well-founded. The method of averaging the minimum and maximum slopes to estimate the best-fit slope and its uncertainty, though simpler, doesn't always provide a robust picture, especially in cases where the data might be noisy or the uncertainties are asymmetric. The approach could indeed lead to a misleading interpretation of the data's precision and accuracy.
#
# When uncertainties are asymmetric, like in your example $ (4 + 0.1 - 0.2) \, \text{s}^2/\text{m} $, it indicates that the error distribution around the measured values is not uniform. This situation can arise due to various factors affecting the measurements in a non-symmetric manner, such as systematic errors in one direction, or when the process being measured inherently has a non-linear response within the range of the measured values.
#
# The linear regression analysis to find the best-fit line, accompanied by careful consideration of the error bars for maximum and minimum slopes, offers a more nuanced understanding. This method respects the distribution and range of the data, providing a more accurate representation of both the central tendency (the slope) and the variability (uncertainty) of the measurements. It's crucial, especially in scientific experiments, to represent data and uncertainties accurately to ensure that conclusions drawn from the data are reliable and valid.
#
# Your approach highlights the importance of rigorous data analysis techniques and the need to critically assess simpler methods, especially when they might oversimplify or misrepresent the underlying uncertainties.

# %% [markdown]
# excellent! it's nice to see you grok the principles of basic physics
# now calculate g with uncertainties

# %% [markdown]
# Given the estimated slope of the line of best fit as $ (4 \pm 1) \, \text{s}^2/\text{m} $, we can calculate the acceleration due to gravity $ g $ with uncertainties. The slope of the $ T^2 $ vs. $ L $ graph in our pendulum experiment is related to $ g $ by the formula:
#
# $ \text{slope} = \frac{4\pi^2}{g} $
#
# From this, we can solve for $ g $:
#
# $ g = \frac{4\pi^2}{\text{slope}} $
#
# Given the slope as $ (4 \pm 1) \, \text{s}^2/\text{m} $, we'll calculate $ g $ using the central value of the slope (4 $ \text{s}^2/\text{m} $) and then determine the range of $ g $ using the slope plus and minus its uncertainty (3 $ \text{s}^2/\text{m} $ and 5 $ \text{s}^2/\text{m} $, respectively). This will give us $ g $ with its uncertainties.
#
# Let's proceed with these calculations.
#
# Using the estimated slope of the line of best fit $ (4 \pm 1) \, \text{s}^2/\text{m} $ for the $ T^2 $ vs. $ L $ graph, we calculate the acceleration due to gravity $ g $ as follows:
#
# - The central value of $ g $ is approximately $ 9.87 \, \text{m/s}^2 $.
# - Considering the uncertainties in the slope, the range of $ g $ is estimated to be between $ 7.90 \, \text{m/s}^2 $ and $ 13.16 \, \text{m/s}^2 $.
#
# This approach, using the central value and accounting for the uncertainties in the slope, gives us a broad range for $ g $, highlighting the impact of measurement precision on our ability to accurately determine physical constants. While the central value is close to the commonly accepted value of $ 9.81 \, \text{m/s}^2 $, the wide range due to the large uncertainty in the slope underlines the importance of precise measurements and careful analysis in experimental physics.

# %% [markdown]
# Quoting the result properly with uncertainty involves presenting $ g $ as $ g \pm \Delta g $, where $ \Delta g $ is the uncertainty in $ g $. The uncertainty is half the range spanned by the minimum and maximum values calculated for $ g $. We also need to ensure that we round off the uncertainty (and the central value of $ g $) according to standard rules for significant figures and uncertainty reporting.
#
# Given the calculated values:
# - Central value of $ g $: $ 9.87 \, \text{m/s}^2 $
# - Minimum value of $ g $: $ 7.90 \, \text{m/s}^2 $
# - Maximum value of $ g $: $ 13.16 \, \text{m/s}^2 $
#
# Let's calculate $ \Delta g $ and then round off the values appropriately.
#
# The acceleration due to gravity, taking into account the uncertainties from our measurements and calculations, can be properly quoted as $ g = 9.87 \pm 2.63 \, \text{m/s}^2 $.
#
# This representation follows the rules for rounding off and reporting uncertainties, presenting both the estimated value and its uncertainty with appropriate precision.

# %%
# Calculate the uncertainty in g as half the range spanned by g_min and g_max
delta_g = (g_max - g_min) / 2

# Properly rounded off result for g and its uncertainty
g_rounded = round(g_central, 2)  # Round g to two decimal places as a reasonable choice
delta_g_rounded = round(delta_g, 2)  # Round the uncertainty to match the precision of g

g_rounded, delta_g_rounded
# Out:
# (9.87, 2.63)

# %% [markdown]
# ok, we need parentheses around both values to indicate the unit applies to both (and there may be a scale multiplier outside the parens as well, for other values) and typically I have a precision of 1 sig fig for the error unless it begins with a 1 or ends with a 5 so
#
# g=(10+/-3)m/s^2
#
# what do you think?

# %% [markdown]
# Your approach aligns well with standard practices for reporting measurements and their uncertainties in the scientific community. The format $ g = (10 \pm 3) \, \text{m/s}^2 $ clearly communicates the result and its uncertainty, including the unit for both. The rounding to $ 10 \, \text{m/s}^2 $ for the central value and to $ 3 \, \text{m/s}^2 $ for the uncertainty follows the convention of maintaining one significant figure in the uncertainty, unless it starts with a 1 (or, as you've mentioned, ends with a 5, which is a common practice for further precision without overly stating certainty).
#
# This format effectively balances the need for precision and clarity without overstating the accuracy of the measurement. The adjustment to a single significant figure in the uncertainty (unless starting with a 1) simplifies communication and acknowledges the inherent limitations of the measurement's precision. Your suggested format and rounding principles indeed reflect a thoughtful approach to presenting scientific data.

# %% [markdown]
# indeed, spurious precision leads to false reporting of accuracy. Precision is meaningless at best (it can be harmful) when it is not accurate

# %% [markdown]
# Exactly, you've hit on a crucial point in scientific measurement and reporting. Precision and accuracy are often confused, but they refer to different concepts:
#
# - **Precision** refers to the closeness of two or more measurements to each other. You can achieve high precision without being accurate if your measurements are consistently off from the true value by the same amount.
# - **Accuracy** refers to the closeness of a measurement to the true value. An accurate measurement is close to the true value, regardless of how close subsequent measurements are to each other.
#
# Reporting with spurious precision—implying a higher degree of exactness than the measurement process allows—can indeed be misleading. It suggests a level of confidence in the measurement that isn't justified, potentially leading to incorrect conclusions or decisions based on the data.
#
# Balancing precision with accuracy, and reporting measurements in a way that reflects both the capabilities of the measurement process and the inherent uncertainties, is essential for clear and honest communication of scientific results. Your emphasis on avoiding overstatement of precision as a means to convey false accuracy is an important principle in both scientific research and reporting.

# %% [markdown]
# Having said that, it is important to justify what has been reported with a discussion of the methods used in the analysis, including the propagation of errors and the correct rounding of results so that spurious precision does not imply false accuracy

# %% [markdown]
# Absolutely, the justification of reported results through a detailed discussion of the methods used, including how errors are propagated and results are rounded, is a cornerstone of rigorous scientific analysis. This approach ensures transparency and reproducibility, which are critical for the advancement of knowledge and for maintaining trust in scientific findings. Here are key aspects that should be covered:
#
# ### Methodology
#
# - **Experimental Setup**: Detailed description of the experimental setup, including equipment used, experimental conditions, and the procedure followed, allows others to replicate the study or understand potential sources of error or bias.
# - **Measurement Techniques**: Explaining how measurements were taken, including any steps taken to reduce measurement error or bias, helps in assessing the reliability of the data.
#
# ### Error Analysis
#
# - **Error Sources**: Identifying and discussing potential sources of error (systematic and random) in the measurements and analysis. This includes instrument precision, environmental factors, and human error.
# - **Uncertainty Estimation**: Detailing how uncertainties were estimated for each measurement. This could involve statistical analysis of repeated measurements, manufacturer specifications for instruments, or theoretical considerations.
# - **Error Propagation**: Describing how errors were propagated through calculations. This should include formulas used for propagation in complex calculations and the rationale behind choosing those methods.
#
# ### Data Analysis
#
# - **Statistical Methods**: Outlining the statistical methods used to analyze the data, including any software or algorithms. This might include regression analysis, hypothesis testing, or other statistical techniques.
# - **Rounding and Reporting**: Explaining the rationale behind the significant figures and rounding rules used, based on the precision of the measurements and the propagated uncertainties.
#
# ### Conclusion Justification
#
# - **Result Interpretation**: Discussing how the results and their uncertainties affect the conclusions drawn from the study. This might involve comparing findings with theoretical predictions or previous studies.
# - **Limitations and Future Work**: Acknowledging the study's limitations and suggesting areas for future research to address unanswered questions or improve upon the current study's methodology.
#
# Including these elements in the reporting of scientific work not only justifies the results and their presentation but also strengthens the scientific method by ensuring that analyses are conducted and reported with careful consideration of accuracy, precision, and transparency. This approach fosters a culture of accountability and continuous improvement in scientific research.

# %% [markdown]
# Nice, use the above analysis to create a report for the experiment. We need a title, an abstract stating what was done and what was found (very short no more that a couple of lines), a method discussion, a results section (the graph and table) with data reductions such as uncertainties and a calculation of the value of g, and finally a conclusion where the results are discussed and suggestions for other experiments are proposed. Use third person past tense.

# %% [markdown]
# ### Title
#
# Determination of the Acceleration Due to Gravity Using a Simple Pendulum
#
# ### Abstract
#
# This experiment aimed to determine the acceleration due to gravity ($g$) by analyzing the oscillation period of a simple pendulum at varying lengths. The value of $g$ was found to be $10 \pm 3$ m/s$^2$, consistent with the expected range of gravitational acceleration near the Earth's surface.
#
# ### Method
#
# The experiment was conducted using a pendulum consisting of a small bob suspended by a string of variable length. Lengths ranged from 0.1 m to 0.5 m, measured in 0.1 m increments. The pendulum was displaced by a small angle to initiate oscillation, ensuring that the motion approximated simple harmonic motion. The period of oscillation ($T$) was recorded for ten complete swings at each length, and the mean value was calculated to minimize timing errors.
#
# Uncertainty in the period measurements was estimated based on the standard deviation of repeated measurements, with a presumed uncertainty of $0.1$ s. The length of the pendulum was measured with a precision of $1 \times 10^{-3}$ m. Error propagation techniques were applied to account for these uncertainties in the final calculation of $g$.
#
# ### Results
#
# The relationship between the square of the period ($T^2$) and the length ($L$) of the pendulum was plotted, revealing a linear relationship as predicted by the theoretical model. The slope of the best-fit line, determined through linear regression, was used to calculate $g$, with error bars and uncertainty analysis incorporated to account for measurement errors.
#
# | Length $L$ (m) | Period $T$ (s) | Error in $T^2$ ($s^2$) |
# |------------------|------------------|----------------------------|
# | 0.1              | 0.63             | 0.13                       |
# | 0.2              | 0.90             | 0.18                       |
# | 0.3              | 1.10             | 0.22                       |
# | 0.4              | 1.27             | 0.25                       |
# | 0.5              | 1.42             | 0.28                       |
#
# The calculated value of $g$, considering the slope of the line of best fit and its uncertainty, was $10 \pm 3$ m/s$^2$.
#
# ### Conclusion
#
# The experiment successfully estimated the acceleration due to gravity to be $10 \pm 3$ m/s$^2$, demonstrating the effectiveness of a simple pendulum in gravitational studies. The significant uncertainty in $g$ underscores the need for precise measurement and error analysis techniques. Future experiments could reduce uncertainty by employing more precise timing methods, such as electronic timing gates, and exploring the effects of air resistance and amplitude on the pendulum's period to refine the value of $g$. This study highlights the importance of error analysis and suggests that with improved precision, simple pendulum experiments can yield highly accurate measurements of physical constants.

# %% [markdown]
# you are probably very busy and did indeed draw a very nice graph earlier, so I will forgive you for not drawing it again :) One last thing it is VERY IMPORTANT to quote results with uncertainties using parentheses! for example the density of steel is (8.3 +/- 0.1) x 10^3 Kg/M^3 do you follow? we need to make sure that the unit and multiplier are distributed correctly!

# %% [markdown]
# Yes, I understand the importance of properly formatting results with uncertainties. When quoting such results, it is crucial to use parentheses to ensure that the uncertainty, unit, and any scale multiplier are correctly associated with the measured value. This convention helps avoid any ambiguity and ensures that the uncertainty is clearly understood as part of the measurement.
#
# For instance, the density of steel should be reported as $ (8.3 \pm 0.1) \times 10^3 $ kg/m$^3$, where the parentheses enclose the central value and the uncertainty, and the multiplier $ \times 10^3 $ and the unit kg/m$^3$ are applied to the entire value within the parentheses. This notation makes it clear that the uncertainty is part of the measured value and that both the value and the uncertainty are subject to the same scale factor.
#
# Ensuring clarity in how results and uncertainties are presented is fundamental in scientific communication, as it provides a precise and unambiguous understanding of the measurements.

# %%
# Given slope and its uncertainty
slope = 4  # s^2/m
slope_uncertainty = 1  # s^2/m

# Slopes for calculating uncertainties in g
slope_min = slope - slope_uncertainty  # Minimum slope
slope_max = slope + slope_uncertainty  # Maximum slope

# Calculate g using the central value of the slope
g_central = 4 * pi**2 / slope

# Calculate g using the minimum and maximum slopes to find the range of g
g_min = 4 * pi**2 / slope_max
g_max = 4 * pi**2 / slope_min

g_central, g_min, g_max
# Out:
# (9.869604401089358, 7.895683520871486, 13.159472534785811)

# %% [markdown]
# very nice, well done, I give you an 8/10, keep up the good work :)

# %% [markdown]
# Thank you very much! I appreciate your feedback and will strive to do even better. If you have more questions or need further assistance in the future, feel free to reach out. Keep up your curiosity and exploration in science! 😊

# %% [markdown]
# ##Implementation:

# %% [markdown]
# ##Testing:

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Constants and parameters
m = 10.0  # mass (kg)
l0 = 10.0  # natural length of the spring (m)
k = 20.0  # spring constant (N/m)
g = 9.81  # gravitational acceleration (m/s^2)

# Equations of motion for the system
def eom(t, y):
    x, x_dot, theta, theta_dot = y
    x_ddot = (l0 + x) * theta_dot**2 - (k / m) * x + g * np.cos(theta)
    theta_ddot = -(g * np.sin(theta) + 2 * x_dot * theta_dot) / (l0 + x)
    return [x_dot, x_ddot, theta_dot, theta_ddot]

# Initial conditions: [x, x_dot, theta, theta_dot]
# Small initial displacement and velocity for both x and theta
initial_conditions = [0.1, 0, 0.1, 0]

# Time span for the simulation
t_span = [0, 100]  # 10 seconds
t_eval = np.linspace(t_span[0], t_span[1], 3000)  # time points to evaluate the solution

# Solve the equations of motion
solution = solve_ivp(eom, t_span, initial_conditions, t_eval=t_eval, method='RK45')

# Plotting the results
plt.figure(figsize=(12, 6))

# Plot x vs. time
plt.subplot(1, 2, 1)
plt.plot(solution.t, solution.y[0])
plt.title('Spring Extension (x) vs. Time')
plt.xlabel('Time (s)')
plt.ylabel('Spring Extension (x) (m)')

# Plot theta vs. time
plt.subplot(1, 2, 2)
plt.plot(solution.t, solution.y[2])
plt.title('Pendulum Angle (θ) vs. Time')
plt.xlabel('Time (s)')
plt.ylabel('Angle (θ) (radians)')

plt.tight_layout()
plt.show()

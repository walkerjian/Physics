# %% [markdown]
# <a href="https://colab.research.google.com/github/walkerjian/Physics/blob/main/roTaters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imagine we have a solid sphere, rotating on it's axis of spin.
#
#
# Let's explore the physics of a rotating solid sphere. I'll walk you through the key concepts and mathematical descriptions involved.
#
# For a solid sphere rotating about its axis of symmetry, we'll consider several important aspects:
#
# 1. Moment of Inertia
# The moment of inertia (I) for a solid sphere is crucial in understanding its rotational dynamics. It's calculated as:
#
# $$I = \frac{2}{5}MR^2$$
#
# Where:
# - M is the total mass of the sphere
# - R is the radius of the sphere
#
# 2. Angular Velocity
# If the sphere is rotating with an angular velocity ω (omega), its rotational kinetic energy will be:
#
# $$E_{rotational} = \frac{1}{2}I\omega^2$$
#
# 3. Rotational Dynamics
# The sphere's rotation is governed by the principle of conservation of angular momentum. If no external torques are applied, the sphere will continue rotating at a constant angular velocity.
#
# Would you like me to elaborate on any of these aspects? I can dive deeper into the mathematics, discuss potential scenarios like precession, or explore how factors like friction or external forces might affect the sphere's rotation.
#
# thanks, we also have angular momentum too
#
#
# You're right! Angular momentum is a key concept when discussing rotating objects. For a solid sphere, the angular momentum (L) is given by the product of its moment of inertia and angular velocity:
#
# $$L = I\omega$$
#
# So, using our previous moment of inertia formula:
#
# $$L = \frac{2}{5}MR^2\omega$$
#
# Some important properties of angular momentum:
# - It's a vector quantity, pointing along the axis of rotation
# - For a rigid body rotating about a fixed axis, angular momentum remains constant in the absence of external torques
# - The direction of angular momentum follows the right-hand rule: if you curl the fingers of your right hand in the direction of rotation, your thumb points in the direction of the angular momentum vector
#
# A few interesting implications:
# - If the sphere changes its shape or distribution of mass, its moment of inertia would change
# - If the angular velocity changes while the moment of inertia remains constant, the angular momentum will change proportionally
#
# Would you like to explore any specific aspects of angular momentum in a rotating sphere?
#
# so, a couple of things, suppose instead of a rotating sphere, we have a rotating black hole (intermediate mass) - what are the corresponding angular measures for it?
#
# Great question! For a rotating black hole, we use concepts from general relativity, particularly the parameter known as the Kerr metric. The key angular measure for a rotating black hole is its spin parameter, often denoted as 'a' or 'j'.
#
# The spin parameter is a dimensionless quantity that ranges from 0 (non-rotating) to 1 (maximally rotating), defined as:
#
# $$a = \frac{J c}{G M^2}$$
#
# Where:
# - J is the angular momentum
# - c is the speed of light
# - G is the gravitational constant
# - M is the mass of the black hole
#
# For an intermediate mass black hole (IMBH), which typically ranges from 100 to 100,000 solar masses, this spin parameter becomes particularly interesting. Unlike classical rotational mechanics, a black hole's rotation affects spacetime itself - it actually drags spacetime around with it in a phenomenon called frame-dragging or the Lense-Thirring effect.
#
# The event horizon's shape and size are directly influenced by this spin parameter. A maximally rotating black hole (a = 1) will have a distinctly different geometry compared to a non-rotating one.
#
# Would you like me to elaborate on how this spin parameter manifests in the black hole's physical characteristics?
#
# Elaborate, but also try to give me the moment of inertia, etc
#
# Let's dive into the details of a rotating black hole's characteristics.
#
# Moment of Inertia:
# For a Kerr black hole, the moment of inertia is more complex than for a classical rigid body. It can be approximated as:
#
# $$I \approx \frac{2}{3}M R_{horizon}^2$$
#
# Where:
# - M is the black hole's mass
# - R_{horizon} is the radius of the event horizon
#
# Angular Momentum Characteristics:
# The angular momentum J is related to the spin parameter a by:
#
# $$J = \frac{G M^2 a}{c}$$
#
# Rotational Energy:
# The rotational energy of a spinning black hole is given by:
#
# $$E_{rot} = \frac{1}{2}I\omega^2$$
#
# However, for black holes, we typically use the spin parameter a instead of angular velocity.
#
# Interesting Physical Implications:
# 1. Ergosphere: A rotating black hole creates an ergosphere, a region outside the event horizon where it's impossible to stand still relative to distant space. Any object in this region is forced to rotate with the black hole.
#
# 2. Frame-Dragging: The black hole literally twists spacetime around itself. Near a maximally rotating black hole (a = 1), spacetime is dragged so intensely that an object would need to move faster than light to remain stationary.
#
# 3. Event Horizon Geometry:
# - Non-rotating (a = 0): Perfectly spherical event horizon
# - Rotating (0 < a ≤ 1): Event horizon becomes oblate, flattened at the poles
# - Maximally rotating (a = 1): Significant distortion of the event horizon shape
#
# 4. Penrose Process: In a rotating black hole, it's theoretically possible to extract rotational energy. An object split near the ergosphere could have one part fall into the black hole while the other escapes with more energy than the original object.
#
# The mathematics becomes increasingly complex as you approach the extreme limits of rotation, involving advanced general relativistic calculations that go beyond classical rotational mechanics.
#
# Would you like me to elaborate on any of these points or explore the mathematical intricacies further?
#
# please keep going! and consider a rotational velocity that is faster than the speed of light at the 'surface' of the black hole :)
#
# Let's explore this fascinating scenario by diving into the physics of extreme rotation!
#
# First, it's crucial to understand the concept of the photon sphere for a rotating black hole. In the Kerr metric, there's a critical radius where the rotational velocity would theoretically reach the speed of light. This is different from the event horizon - it's a region where light can orbit the black hole in a circular path.
#
# For a maximally rotating black hole (a = 1), the photon sphere becomes dramatically distorted. The condition for a rotational velocity at the speed of light occurs at a radius where:
#
# $$v_{rot} = c$$
#
# However, this leads to some mind-bending physics:
#
# 1. Theoretical Limit: As the rotational velocity approaches c, spacetime itself becomes fundamentally warped. The black hole's angular velocity reaches a point where local spacetime is effectively being "torn apart".
#
# 2. Ergosphere Dynamics: Near this extreme rotation, the ergosphere expands dramatically. Objects within this region experience extreme frame-dragging - essentially, spacetime itself is being forced to rotate.
#
# 3. Angular Momentum Paradox: As you approach this limit, the relationship between angular momentum and rotation becomes non-linear. The traditional formulas break down, and we enter a regime where quantum mechanical and gravitational effects become inextricably linked.
#
# Mathematically, this approaches a singularity where:
#
# $$\lim_{v_{rot} \to c} (spacetime curvature) \to \infty$$
#
# Fascinating implications:
# - The black hole effectively becomes a kind of "cosmic whirlpool" in spacetime
# - Information and causality become extremely distorted
# - The boundary between classical and quantum physics becomes blurred
#
# Interestingly, this scenario touches on the theoretical limits of rotation in the universe. It's a point where our current understanding of physics begins to break down, suggesting we're approaching a fundamental boundary of physical description.
#
# Would you like me to elaborate on how these extreme rotational conditions challenge our current models of physics? The intersection of quantum mechanics, general relativity, and these extreme rotational states is particularly intriguing!
#
# Let's delve deeper into the fascinating frontier where extreme rotation challenges our fundamental understanding of physics.
#
# At the extreme rotational limits, we encounter several profound theoretical boundaries:
#
# 1. Quantum Gravity Threshold
# As rotational velocity approaches light speed, we enter a regime where quantum mechanical effects and gravitational effects become fundamentally inseparable. This is precisely the domain where a complete theory of quantum gravity becomes essential.
#
# The traditional separation between quantum mechanics (governing microscopic interactions) and general relativity (governing macroscopic gravitational effects) completely breaks down. We're looking at a scenario where:
#
# $$\text{Quantum Effects} \approx \text{Gravitational Effects}$$
#
# 2. Information Paradox Amplification
# Extreme rotation dramatically intensifies the black hole information paradox. As rotation approaches its theoretical limit, the following occurs:
# - Quantum entanglement becomes maximally distorted
# - Causal relationships between interior and exterior of the black hole become highly non-linear
# - The very concept of "information" begins to lose its classical meaning
#
# 3. Spacetime Topology Transformation
# At extreme rotation, spacetime itself undergoes a topological transformation. It's no longer a smooth, continuous manifold but becomes something more akin to a quantum foam - a seething, dynamic structure where:
# - Spatial dimensions become probabilistic
# - Time loses its unidirectional nature
# - Causality becomes a statistical phenomenon rather than a deterministic process
#
# 4. Quantum Vacuum Dynamics
# The rotational energy becomes so intense that it begins to directly interact with the quantum vacuum. This means:
# - Virtual particle creation becomes asymmetric
# - Vacuum energy becomes dynamically coupled to the rotation
# - Quantum fluctuations are amplified to macroscopic scales
#
# Mathematically, we approach a limit where traditional coordinate systems break down. The coordinate singularity transforms into something more akin to a quantum probability distribution.
#
# $$\lim_{v_{rot} \to c} \text{Spacetime Coordinate} \to \text{Quantum Probability Wave}$$
#
# This is where physics becomes truly mind-bending. We're no longer describing a physical object in a classical sense, but a dynamic quantum-gravitational system that challenges our most fundamental intuitions about space, time, and matter.
#
# Would you like me to elaborate on any of these mind-warping implications? The boundary between known physics and pure theoretical speculation is incredibly exciting!
#
# lets return to the classical rotating sphere for a bit, what happens to the physics if our spinning sphere is also spun around an orthogonal axis?
#
# Excellent question! When a rotating sphere is simultaneously rotated around an orthogonal axis, we enter the fascinating realm of gyroscopic motion, specifically a phenomenon called precession.
#
# Let's break down the physics:
#
# 1. Angular Momentum Vectors
# - First rotation: Angular momentum vector L1
# - Second rotation: Angular momentum vector L2
# - These vectors are now perpendicular to each other
#
# 2. Precession Dynamics
# The sphere will not simply rotate in two independent ways. Instead, it will experience a complex motion where the axis of rotation itself begins to rotate around a third axis. This is described by the gyroscopic equation:
#
# $$\vec{\tau} = \frac{d\vec{L}}{dt}$$
#
# Where τ (tau) is the external torque causing the change in angular momentum.
#
# 3. Moment of Inertia Considerations
# The sphere's moment of inertia now becomes a tensor, not just a scalar. We have different moments of inertia about different axes:
#
# $$I = \begin{bmatrix}
# I_{xx} & 0 & 0 \\
# 0 & I_{yy} & 0 \\
# 0 & 0 & I_{zz}
# \end{bmatrix}$$
#
# 4. Precession Rate
# The precession rate ω_p is given by:
#
# $$\omega_p = \frac{\tau}{L\omega}$$
#
# Where:
# - τ is the applied torque
# - L is the initial angular momentum
# - ω is the initial rotation rate
#
# Would you like me to elaborate on the mathematical or physical implications of this multi-axis rotation?
#
# sure go ahead, then we can completely generalise it and rotate it about the third orthogonal axis :) what happens then? And does it matter what order we do the rotations? Finally we can accelerate the system  by boosting along each rotational axis :)
#
#
# Let's explore this fascinating scenario of multi-axis rotation systematically!
#
# First, the order of rotations actually matters critically - this is a key concept in rotational dynamics known as the non-commutativity of rotations. Unlike translations, rotations don't necessarily follow the commutative property (A × B ≠ B × A).
#
# For our three orthogonal axes (let's call them x, y, and z), the rotation order creates different final states. This leads to what's called the "rotation group SO(3)" - a mathematical representation of three-dimensional rotations.
#
# The most interesting phenomenon emerges from this non-commutativity: each rotation changes the moments of inertia and angular momentum vectors of the subsequent rotations. This creates a complex dynamic where:
#
# 1. First rotation about x-axis
# 2. Then rotation about y-axis
# 3. Then rotation about z-axis
#
# Will NOT produce the same final state as:
# 1. First rotation about z-axis
# 2. Then rotation about x-axis
# 3. Then rotation about y-axis
#
# Mathematically, this is represented by the cross-product of rotation matrices, which do not commute.
#
# When we add acceleration along each rotational axis, we're essentially introducing relativistic transformations. This means:
# - Each boost changes the object's mass
# - Rotation axes get length-contracted
# - Time dilation occurs differently for each rotational frame
#
# Would you like me to derive the mathematical formalism for these transformations? The physics gets wonderfully complex at this point!
#
# Yes please - iam mathematically spohisticated ;)
#
#
# I'll develop this systematically using tensor notation and relativistic transformations.
#
# Let's define our rotation and boost matrices using the fundamental representations:
#
# Rotation Matrix (for rotation about z-axis by angle θ):
# $$R_z(\theta) = \begin{pmatrix}
# \cos\theta & -\sin\theta & 0 \\
# \sin\theta & \cos\theta & 0 \\
# 0 & 0 & 1
# \end{pmatrix}$$
#
# Lorentz Boost Matrix (along x-axis with velocity v):
# $$\Lambda_x(v) = \begin{pmatrix}
# \gamma & -\gamma\beta & 0 \\
# -\gamma\beta & \gamma & 0 \\
# 0 & 0 & 1
# \end{pmatrix}$$
#
# Where:
# - $$\gamma = \frac{1}{\sqrt{1-\beta^2}}$$
# - $$\beta = \frac{v}{c}$$
#
# The non-commutativity emerges when we multiply these matrices in different orders. The commutator $$[R_z, \Lambda_x] \neq 0$$ becomes a key mathematical object.
#
# Would you like me to elaborate on the tensor formalism or the group-theoretic implications of these transformations?
#
# sure, but there are some issues - the equations are looking like alphbet soup :(
#
#
# You're right. Let me refactor and clarify the mathematical representation with more precision.
#
# Consider SO(3) - the Special Orthogonal Group in 3 dimensions. Our rotation matrices form a Lie group with non-commutative properties. The core mathematical object becomes the angular momentum tensor $$\mathbf{L}$$, which transforms under rotations and boosts.
#
# The generalized rotation tensor can be represented as:
#
# $$\mathbf{R} = \exp(\hat{\omega})$$
#
# Where $$\hat{\omega}$$ is the angular velocity bivector, capturing rotational dynamics across all three orthogonal axes simultaneously.
#
# The Lorentz transformation introduces additional complexity through the Poincaré group, where rotations and boosts do not commute. The key mathematical structure becomes a representation of how angular momentum transforms under coordinate changes.
#
# Would you like me to elaborate on the group-theoretic structure, or dive deeper into the transformation properties of this system?
#
# The beauty here is that we're approaching a region where classical mechanics, special relativity, and group theory intersect elegantly.
#
# before you move on, i wold like to consider if it is possible to rotate a sphere about 3 orthoganal axes in the real world? The classical gimballed apparatus does not seem to be right, am i right?
#
#
# Excellent observation! You've hit upon a fundamental physical constraint.
#
# In classical mechanics, simultaneously rotating a rigid body about three perfectly orthogonal axes is impossible. Here's why:
#
# 1. Physical Constraints:
# - Any real mechanical system will introduce coupling between rotation axes
# - Perfect orthogonality requires infinitely rigid body and perfect frictionless joints
# - Mechanical constraints always introduce some degree of non-orthogonality
#
# 2. Gimbal Limitations:
# - Traditional gimbal systems can only provide two-axis rotation
# - The third axis will always be constrained or imperfectly realized
# - Each additional rotation introduces mechanical coupling and energy loss
#
# 3. Quantum Mechanical Alternative:
# Interestingly, at the quantum scale, certain systems like nitrogen-vacancy centers in diamond can exhibit more complex rotational behaviors that approach your thought experiment.
#
# The closest real-world approximations would be:
# - Precision optical systems using laser-controlled rotation
# - Advanced electromagnetic suspension systems
# - Quantum mechanical spin systems
#
# Your intuition is correct - a perfect three-axis orthogonal rotation is a theoretical construct that breaks down in physical implementation.
#
# Would you like me to elaborate on the mechanical or quantum mechanical constraints that prevent this idealized rotation?
#
# Let's walk through the physical process of trying to spin a sphere or disc about multiple axes.
#
# First spin axis: No problem. The object rotates cleanly around its initial axis.
#
# Second spin axis: When you try to introduce rotation about a second orthogonal axis, you encounter the first significant mechanical challenge. The rotation introduces torque and precession, which means the original axis of rotation will start to wobble.
#
# Third spin axis attempt: This is where the real complexity emerges. The mechanical coupling becomes critical:
#
# 1. Mechanical Coupling
# - Each new rotation axis introduces internal stresses
# - The material's elastic properties start to dominate
# - Rotational energy is partially converted to deformation energy
#
# 2. Angular Momentum Conservation
# The system will seek to conserve total angular momentum. This means:
# - Introducing the third rotation axis causes complex precession
# - The original two rotation axes will begin to destabilize
# - Energy is distributed across unexpected modes of motion
#
# 3. Material Failure Modes
# - At high rotational speeds, the material will likely fail
# - Stress concentrations build up at the rotation axes
# - Potential failure mechanisms include:
#   - Shear fracture
#   - Internal delamination
#   - Molecular bond disruption
#
# Mathematically, this becomes a non-linear dynamic system where:
# - Initial conditions become critically important
# - Small perturbations can lead to dramatically different outcomes
# - Predictability breaks down rapidly
#
# The fundamental issue is that real materials are not perfectly rigid. Each rotation axis introduces internal stresses that couple and interact in complex ways.
#
# Would you like me to elaborate on the specific failure mechanisms or the mathematical description of this coupling?
#
# the math of the coupling would be great
#
#
# Let's develop the mathematical model of rotational coupling.
#
# We'll start with a tensor-based approach representing the coupling between rotation axes. The key tensor is the angular momentum coupling tensor $$\mathbf{C}$$, which captures the interdependence between rotation modes.
#
# The coupling dynamics can be represented by a generalized equation:
#
# $$\frac{d\mathbf{L}}{dt} = \mathbf{C} \cdot \mathbf{L} + \mathbf{\tau}$$
#
# Where:
# - $$\mathbf{L}$$ is the angular momentum vector
# - $$\mathbf{C}$$ is the coupling tensor
# - $$\mathbf{\tau}$$ represents external torques
#
# The coupling tensor $$\mathbf{C}$$ becomes non-diagonal, indicating cross-axis interactions:
#
# $$\mathbf{C} = \begin{pmatrix}
# C_{xx} & C_{xy} & C_{xz} \\
# C_{yx} & C_{yy} & C_{yz} \\
# C_{zx} & C_{zy} & C_{zz}
# \end{pmatrix}$$
#
# The off-diagonal terms $$C_{ij}$$ (where $$i \neq j$$) represent the critical coupling between different rotational axes.
#
# Physically, this means:
# - A rotation about the x-axis influences rotation about y and z
# - The coupling strength depends on material properties
# - At high rotational speeds, these cross-axis interactions become dominant
#
# The full dynamics can be described by a system of coupled differential equations:
#
# $$\begin{aligned}
# \frac{d\omega_x}{dt} &= \sum_{i \neq x} C_{xi}\omega_i \\
# \frac{d\omega_y}{dt} &= \sum_{i \neq y} C_{yi}\omega_i \\
# \frac{d\omega_z}{dt} &= \sum_{i \neq z} C_{zi}\omega_i
# \end{aligned}$$
#
# Would you like me to elaborate on how these coupling terms manifest in different material systems?

# %% [markdown]
# The coupling terms in the equations above manifest due to the material's physical and geometric properties, as well as the rotational dynamics of the system. Let's break this down into specific mechanisms that give rise to these terms.
#
# ### 1. **Material Properties**
#    - **Elasticity**: The material's ability to deform and return to its original shape introduces stresses that couple rotational axes. These stresses act as internal torques, modifying the angular momentum along other axes.
#    - **Anisotropy**: If the material is not isotropic (i.e., its mechanical properties vary with direction), the coupling terms will differ significantly. For example, a sphere made of composite materials will have larger off-diagonal terms in $C$.
#
#    The material's stress-strain relationship contributes to the coupling tensor $C$ through terms like:
#    $$
#    C_{ij} \propto \frac{\sigma_{ij}}{\epsilon_{ij}}
#    $$
#    where $\sigma_{ij}$ is the stress tensor and $\epsilon_{ij}$ is the strain tensor.
#
# ### 2. **Geometry**
#    - **Non-uniform Mass Distribution**: If the sphere is not perfectly homogeneous, the moments of inertia about different axes will differ. This causes angular momentum along one axis to induce motion along others.
#    - **Shape Irregularities**: A perfectly spherical shape minimizes coupling, but slight deviations from sphericity can dramatically increase the off-diagonal terms $C_{ij}$.
#
#    For instance, the moment of inertia tensor $I$ in a coordinate system fixed to the rotating body takes the form:
#    $$
#    I = \begin{bmatrix}
#    I_{xx} & I_{xy} & I_{xz} \\
#    I_{yx} & I_{yy} & I_{yz} \\
#    I_{zx} & I_{zy} & I_{zz}
#    \end{bmatrix}
#    $$
#    The coupling tensor $C$ is derived from the inverse of $I$, accounting for gyroscopic effects.
#
# ### 3. **Gyroscopic Effects**
#    - The rotational velocity vector $\vec{\omega}$ generates gyroscopic torques that act orthogonal to the current angular velocity. These torques are captured in the coupling terms.
#    - For a rotating body with angular velocity $\vec{\omega} = (\omega_x, \omega_y, \omega_z)$, the gyroscopic torque $\vec{\tau}_g$ is:
#      $$
#      \vec{\tau}_g = \vec{\omega} \times (I \cdot \vec{\omega})
#      $$
#      Expanding this expression introduces terms that depend on all three components of $\vec{\omega}$, contributing to the coupling.
#
# ### 4. **Damping and Friction**
#    - **Internal Damping**: As the sphere deforms due to high rotational speeds, internal friction dissipates energy, modifying the effective coupling tensor.
#    - **External Friction**: If the sphere interacts with a medium (like air), drag forces add additional terms to $C$ that further couple the rotational axes.
#
#    These effects can be modeled as:
#    $$
#    C_{ij} \propto -\eta_{ij} \frac{\partial \omega_j}{\partial t}
#    $$
#    where $\eta_{ij}$ is the damping coefficient tensor.
#
# ### 5. **Instability at High Speeds**
#    - At high rotational velocities, centrifugal forces can exceed the material's structural limits, inducing deformation. This deformation changes the moments of inertia dynamically, making $C_{ij}$ time-dependent:
#      $$
#      C_{ij}(t) = C_{ij}^{(0)} + \Delta C_{ij}(t)
#      $$
#      Here, $C_{ij}^{(0)}$ is the static coupling tensor, and $\Delta C_{ij}(t)$ arises from deformation.
#
# ### Solving the Coupled System
# The system of equations for angular velocities becomes:
# $$
# \frac{d\vec{\omega}}{dt} = C \cdot \vec{\omega} + \vec{\tau}
# $$
# This can be solved numerically, as the non-linearity from gyroscopic and deformation effects often prevents closed-form solutions. For small couplings, perturbative methods can approximate solutions:
# $$
# \vec{\omega}(t) = \vec{\omega}(0) + \int_0^t \left(C \cdot \vec{\omega}(t') + \vec{\tau}(t')\right) dt'
# $$
#
# ### Visualization of Coupling
# A phase space representation (e.g., plotting $\omega_x$, $\omega_y$, and $\omega_z$) reveals how the system's rotational state evolves over time. For sufficiently strong coupling, chaotic behavior can emerge, particularly when the system approaches material failure limits.
#
# Would you like to delve deeper into numerical methods for solving these equations or explore experimental setups that demonstrate these principles?

# %% [markdown]
# ### Theoretical Preamble: Rotational Motion and Dynamics
#
# To thoroughly understand the advanced concepts we need to lay down the fundamentals of rotational motion, starting from basic concepts and building up to more advanced ideas like tensors, angular momentum, and boosts.
#
#
# ### 1. **Rotations and Axes of Motion**
# - A **rotation** involves turning a body about an axis, which can be fixed in space or move with the object.
# - A rotation in 3D space is characterized by:
#   - The **axis of rotation**: A line around which the object spins.
#   - The **angular velocity** $ \vec{\omega} $: A vector quantity whose direction follows the right-hand rule and magnitude describes the rate of rotation (in radians per second).
#
#
#
# ### 2. **Moment of Inertia**
# - The **moment of inertia** $ I $ measures an object's resistance to changes in its rotational motion, analogous to mass in linear motion.
# - For a rigid body rotating about an axis, $ I $ depends on:
#   - The mass distribution of the body relative to the axis.
#   - The geometry of the body (e.g., sphere, disk, cylinder).
#
# #### Example: Disk Rotating About an Axis Through Its Center
# - For a uniform disk of mass $ M $, radius $ R $, and thickness $ T $:
#   $$
#   I_z = \frac{1}{2} M R^2 \quad \text{(rotation about the z-axis)}.
#   $$
#   $$
#   I_x = I_y = \frac{1}{4} M R^2 + \frac{1}{12} M T^2 \quad \text{(rotation about x or y-axis)}.
#   $$
#
# #### Generalization: Inertia Tensor
# - In 3D, the moment of inertia is represented as a tensor $ \mathbf{I} $, a 3×3 matrix:
#
#   $$
#   \mathbf{I} =
#   \begin{bmatrix}
#   I_{xx} & I_{xy} & I_{xz} \\
#   I_{yx} & I_{yy} & I_{yz} \\
#   I_{zx} & I_{zy} & I_{zz}
#   \end{bmatrix}.
#   $$
#
# - The diagonal elements represent the moments of inertia about the principal axes, while the off-diagonal terms capture coupling between axes due to asymmetries or off-center masses.
#
#
#
# ### 3. **Angular Velocity and Acceleration**
# - **Angular Velocity** $ \vec{\omega} $: Describes how fast an object rotates and around which axis. In 3D:
#   $$
#   \vec{\omega} = (\omega_x, \omega_y, \omega_z).
#   $$
# - **Angular Acceleration** $ \vec{\alpha} $: The rate of change of angular velocity:
#   $$
#   \vec{\alpha} = \frac{d\vec{\omega}}{dt}.
#   $$
# - These quantities relate to rotational motion in the same way that velocity and acceleration describe linear motion.
#
#
#
# ### 4. **Rotational Kinetic Energy**
# - The rotational analog of translational kinetic energy is:
#   $$
#   KE_{\text{rot}} = \frac{1}{2} \vec{\omega}^T \mathbf{I} \vec{\omega}.
#   $$
#   This equation accounts for the angular velocity vector and the inertia tensor.
#
#
#
# ### 5. **Angular Momentum**
# - **Angular Momentum** $ \vec{L} $: Describes the rotational equivalent of linear momentum:
#   $$
#   \vec{L} = \mathbf{I} \vec{\omega}.
#   $$
# - Angular momentum is conserved in the absence of external torques, analogous to linear momentum conservation in the absence of external forces.
#
#
#
# ### 6. **Boosts Along Axes**
# - **Boosts** refer to changes in velocity along specific axes, often considered in relativistic contexts.
# - In our rotational framework:
#   - A boost along an axis (e.g., x-axis) can modify the distribution of mass and alter the moments of inertia and angular momentum.
#   - These effects become significant in highly dynamic systems.
#
#
#
# ### 7. **Euler Angles**
# - Rotations in 3D can be described using **Euler angles**, a sequence of three rotations about specified axes:
#   - $ \phi $: Rotation about the z-axis.
#   - $ \theta $: Rotation about the x-axis (after the first rotation).
#   - $ \psi $: Final rotation about the z-axis (after the second rotation).
# - The **rotation matrix** $ R $ combining these angles is:
#   $$
#   R = R_z(\psi) R_x(\theta) R_z(\phi).
#   $$
#
# ### Applying the Theory to Our Animation
# 1. **Rotating About Each Axis Sequentially**:
#    - Start by rotating the disk about the x-axis, then add rotations about the y-axis and z-axis. Observe how the orientation evolves.
#    - Inertia tensor and angular momentum are recalculated dynamically for each combination of rotations.
#
# 2. **Exploring Changes in Physical Quantities**:
#    - With angular velocities defined by sliders, compute:
#      - Numerical values for the moment of inertia tensor $ \mathbf{I} $.
#      - Angular momentum $ \vec{L} $ and rotational energy $ KE_{\text{rot}} $.
#    - Visualize these updates in real time.
#
# 3. **Introducing Material Properties**:
#    - For a uniform disk of specific material (e.g., brass, steel), derive:
#      - Mass $ M $ from density.
#      - Corresponding numerical values for all physical quantities.

# %% [markdown]
# The coupling terms in the equations above manifest due to the material's physical and geometric properties, as well as the rotational dynamics of the system. Let's break this down into specific mechanisms that give rise to these terms.
#
# ### 1. **Material Properties**
#    - **Elasticity**: The material's ability to deform and return to its original shape introduces stresses that couple rotational axes. These stresses act as internal torques, modifying the angular momentum along other axes.
#    - **Anisotropy**: If the material is not isotropic (i.e., its mechanical properties vary with direction), the coupling terms will differ significantly. For example, a sphere made of composite materials will have larger off-diagonal terms in $C$.
#
#    The material's stress-strain relationship contributes to the coupling tensor $C$ through terms like:
#    $$
#    C_{ij} \propto \frac{\sigma_{ij}}{\epsilon_{ij}}
#    $$
#    where $\sigma_{ij}$ is the stress tensor and $\epsilon_{ij}$ is the strain tensor.
#
# ### 2. **Geometry**
#    - **Non-uniform Mass Distribution**: If the sphere is not perfectly homogeneous, the moments of inertia about different axes will differ. This causes angular momentum along one axis to induce motion along others.
#    - **Shape Irregularities**: A perfectly spherical shape minimizes coupling, but slight deviations from sphericity can dramatically increase the off-diagonal terms $C_{ij}$.
#
#    For instance, the moment of inertia tensor $I$ in a coordinate system fixed to the rotating body takes the form:
#    $$
#    I = \begin{bmatrix}
#    I_{xx} & I_{xy} & I_{xz} \\
#    I_{yx} & I_{yy} & I_{yz} \\
#    I_{zx} & I_{zy} & I_{zz}
#    \end{bmatrix}
#    $$
#    The coupling tensor $C$ is derived from the inverse of $I$, accounting for gyroscopic effects.
#
# ### 3. **Gyroscopic Effects**
#    - The rotational velocity vector $\vec{\omega}$ generates gyroscopic torques that act orthogonal to the current angular velocity. These torques are captured in the coupling terms.
#    - For a rotating body with angular velocity $\vec{\omega} = (\omega_x, \omega_y, \omega_z)$, the gyroscopic torque $\vec{\tau}_g$ is:
#
#      $$
#      \vec{\tau}_g = \vec{\omega} \times (I \cdot \vec{\omega})
#      $$
#
#      Expanding this expression introduces terms that depend on all three components of $\vec{\omega}$, contributing to the coupling.
#
# ### 4. **Damping and Friction**
#    - **Internal Damping**: As the sphere deforms due to high rotational speeds, internal friction dissipates energy, modifying the effective coupling tensor.
#    - **External Friction**: If the sphere interacts with a medium (like air), drag forces add additional terms to $C$ that further couple the rotational axes.
#
#    These effects can be modeled as:
#    $$
#    C_{ij} \propto -\eta_{ij} \frac{\partial \omega_j}{\partial t}
#    $$
#    where $\eta_{ij}$ is the damping coefficient tensor.
#
# ### 5. **Instability at High Speeds**
#    - At high rotational velocities, centrifugal forces can exceed the material's structural limits, inducing deformation. This deformation changes the moments of inertia dynamically, making $ C_{ij} $ time-dependent:
#
#      $$
#      C_{ij}(t) = C_{ij}^{(0)} + \Delta C_{ij}(t)
#      $$
#
#      Here, $C_{ij}^{(0)}$ is the static coupling tensor, and $\Delta C_{ij}(t)$ arises from deformation.
#
# ### Solving the Coupled System
# The system of equations for angular velocities becomes:
#
# $$
# \frac{d\vec{\omega}}{dt} = C \cdot \vec{\omega} + \vec{\tau}
# $$
#
# This can be solved numerically, as the non-linearity from gyroscopic and deformation effects often prevents closed-form solutions. For small couplings, perturbative methods can approximate solutions:
#
# $$
# \vec{\omega}(t) = \vec{\omega}(0) + \int_0^t \left(C \cdot \vec{\omega}(t') + \vec{\tau}(t')\right) dt'
# $$
#
# ### Visualization of Coupling
# A phase space representation (e.g., plotting $\omega_x$, $\omega_y$, and $\omega_z$) reveals how the system's rotational state evolves over time. For sufficiently strong coupling, chaotic behavior can emerge, particularly when the system approaches material failure limits.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from ipywidgets import interact, FloatSlider

# Function to generate the rotation matrix
def rotation_matrix(axis, angle):
    if axis == "x":
        return np.array([[1, 0, 0],
                         [0, np.cos(angle), -np.sin(angle)],
                         [0, np.sin(angle), np.cos(angle)]])
    elif axis == "y":
        return np.array([[np.cos(angle), 0, np.sin(angle)],
                         [0, 1, 0],
                         [-np.sin(angle), 0, np.cos(angle)]])
    elif axis == "z":
        return np.array([[np.cos(angle), -np.sin(angle), 0],
                         [np.sin(angle), np.cos(angle), 0],
                         [0, 0, 1]])

# Function to draw the disk with rotation
def plot_disk(rotation_x=0, rotation_y=0, rotation_z=0):
    # Disk parameters
    radius = 1.0
    thickness = 0.1
    num_segments = 100

    # Generate the disk
    angles = np.linspace(0, 2 * np.pi, num_segments)
    x_circle = radius * np.cos(angles)
    y_circle = radius * np.sin(angles)
    z_top = thickness / 2 * np.ones_like(x_circle)
    z_bottom = -thickness / 2 * np.ones_like(x_circle)

    # Split into two halves for coloring
    midpoint = num_segments // 2
    top_faces_colored = [
        [x_circle[:midpoint], y_circle[:midpoint], z_top[:midpoint]],
        [x_circle[midpoint:], y_circle[midpoint:], z_top[midpoint:]],
    ]
    bottom_faces_colored = [
        [x_circle[:midpoint], y_circle[:midpoint], z_bottom[:midpoint]],
        [x_circle[midpoint:], y_circle[midpoint:], z_bottom[midpoint:]],
    ]

    # Apply rotations
    combined_rotation = (
        rotation_matrix("z", np.radians(rotation_z)) @
        rotation_matrix("y", np.radians(rotation_y)) @
        rotation_matrix("x", np.radians(rotation_x))
    )
    for i in range(len(top_faces_colored)):
        top_faces_colored[i] = combined_rotation @ np.array(top_faces_colored[i])
        bottom_faces_colored[i] = combined_rotation @ np.array(bottom_faces_colored[i])

    # Create the plot
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.5, 1.5])

    # Draw the disk
    top_colors = ['red', 'green']
    bottom_colors = ['blue', 'yellow']
    for i, color in enumerate(top_colors):
        ax.plot_trisurf(*top_faces_colored[i], color=color, alpha=0.6)
    for i, color in enumerate(bottom_colors):
        ax.plot_trisurf(*bottom_faces_colored[i], color=color, alpha=0.6)

    # Set labels
    ax.set_xlabel("X-axis")
    ax.set_ylabel("Y-axis")
    ax.set_zlabel("Z-axis")
    plt.show()

# Create interactive sliders
interact(
    plot_disk,
    rotation_x=FloatSlider(min=0, max=360, step=1, value=0, description="Rotate X"),
    rotation_y=FloatSlider(min=0, max=360, step=1, value=0, description="Rotate Y"),
    rotation_z=FloatSlider(min=0, max=360, step=1, value=0, description="Rotate Z"),
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Rotate X', max=360.0, step=1.0), FloatSlider(value=0…
# <function __main__.plot_disk(rotation_x=0, rotation_y=0, rotation_z=0)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, FloatSlider

# Doughnut Geometry
def doughnut_points(R=1.0, r=0.3, n_major=50, n_minor=30):
    u = np.linspace(0, 2 * np.pi, n_major)
    v = np.linspace(0, 2 * np.pi, n_minor)
    u, v = np.meshgrid(u, v)
    x = (R + r * np.cos(v)) * np.cos(u)
    y = (R + r * np.cos(v)) * np.sin(u)
    z = r * np.sin(v)
    return x, y, z

# Plot the Doughnut
def plot_doughnut(toroidal_rot=0, spin_x=0, spin_y=0, spin_z=0):
    R, r = 1.0, 0.3  # Major and minor radii
    x, y, z = doughnut_points(R, r)

    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.0, 1.0])

    # Plot the torus
    ax.plot_surface(x, y, z, color='lightblue', alpha=0.6, edgecolor='gray')

    # Add rotation vectors
    ax.quiver(0, 0, 0, 0, 0, 1, color='red', label=r"$\omega_z$")
    ax.quiver(0, 0, 0, 0, 1, 0, color='green', label=r"$\omega_y$")
    ax.quiver(0, 0, 0, 1, 0, 0, color='blue', label=r"$\omega_x$")
    ax.text(0, 0, 1.2, "Toroidal Rotation", color='purple')

    # Title and legend
    ax.set_title("Rotating Doughnut with Toroidal Motion", fontsize=14)
    ax.legend()
    plt.show()

# Interactive Controls
interact(
    plot_doughnut,
    toroidal_rot=FloatSlider(min=0, max=10, step=0.1, value=0, description="Toroidal Rot"),
    spin_x=FloatSlider(min=0, max=5, step=0.1, value=0, description="Spin X"),
    spin_y=FloatSlider(min=0, max=5, step=0.1, value=0, description="Spin Y"),
    spin_z=FloatSlider(min=0, max=5, step=0.1, value=0, description="Spin Z")
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Toroidal Rot', max=10.0), FloatSlider(value=0.0, des…
# <function __main__.plot_doughnut(toroidal_rot=0, spin_x=0, spin_y=0, spin_z=0)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, FloatSlider

# Doughnut Geometry
def doughnut_points(R=1.0, r=0.3, n_major=50, n_minor=30, toroidal_rot=0):
    u = np.linspace(0, 2 * np.pi, n_major)
    v = np.linspace(0, 2 * np.pi, n_minor)
    u, v = np.meshgrid(u, v)
    x = (R + r * np.cos(v)) * np.cos(u + toroidal_rot)
    y = (R + r * np.cos(v)) * np.sin(u + toroidal_rot)
    z = r * np.sin(v)
    return x, y, z

# Rotation Matrix
def rotation_matrix(axis, angle):
    if axis == "x":
        return np.array([[1, 0, 0],
                         [0, np.cos(angle), -np.sin(angle)],
                         [0, np.sin(angle), np.cos(angle)]])
    elif axis == "y":
        return np.array([[np.cos(angle), 0, np.sin(angle)],
                         [0, 1, 0],
                         [-np.sin(angle), 0, np.cos(angle)]])
    elif axis == "z":
        return np.array([[np.cos(angle), -np.sin(angle), 0],
                         [np.sin(angle), np.cos(angle), 0],
                         [0, 0, 1]])

# Apply rotations to the doughnut
def rotate_doughnut(x, y, z, spin_x, spin_y, spin_z):
    coords = np.vstack([x.ravel(), y.ravel(), z.ravel()])
    rotation = (
        rotation_matrix("x", spin_x) @
        rotation_matrix("y", spin_y) @
        rotation_matrix("z", spin_z)
    )
    rotated_coords = rotation @ coords
    return rotated_coords[0].reshape(x.shape), rotated_coords[1].reshape(y.shape), rotated_coords[2].reshape(z.shape)

# Plot the Doughnut
def plot_doughnut(toroidal_rot=0, spin_x=0, spin_y=0, spin_z=0):
    R, r = 1.0, 0.3  # Major and minor radii
    x, y, z = doughnut_points(R, r, toroidal_rot=toroidal_rot)
    x, y, z = rotate_doughnut(x, y, z, spin_x, spin_y, spin_z)

    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.0, 1.0])

    # Plot the torus
    ax.plot_surface(x, y, z, color='lightblue', alpha=0.6, edgecolor='gray')

    # Add rotation vectors
    ax.quiver(0, 0, 0, 0, 0, 1, color='red', label=r"$\omega_z$")
    ax.quiver(0, 0, 0, 0, 1, 0, color='green', label=r"$\omega_y$")
    ax.quiver(0, 0, 0, 1, 0, 0, color='blue', label=r"$\omega_x$")
    ax.text(0, 0, 1.2, "Toroidal Rotation", color='purple')

    # Title and legend
    ax.set_title("Rotating Doughnut with Toroidal Motion", fontsize=14)
    ax.legend()
    plt.show()

# Interactive Controls
interact(
    plot_doughnut,
    toroidal_rot=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Toroidal Rot"),
    spin_x=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin X"),
    spin_y=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Y"),
    spin_z=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Z")
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Toroidal Rot', max=6.283185307179586), FloatSlider(v…
# <function __main__.plot_doughnut(toroidal_rot=0, spin_x=0, spin_y=0, spin_z=0)>

# %%
def doughnut_points(R=1.0, r=0.3, n_major=50, n_minor=30, toroidal_rot=0, poloidal_rot=0):
    u = np.linspace(0, 2 * np.pi, n_major)  # Major angle (toroidal)
    v = np.linspace(0, 2 * np.pi, n_minor)  # Minor angle (poloidal)
    u, v = np.meshgrid(u, v)

    # Apply toroidal and poloidal rotations
    x = (R + r * np.cos(v + poloidal_rot)) * np.cos(u + toroidal_rot)
    y = (R + r * np.cos(v + poloidal_rot)) * np.sin(u + toroidal_rot)
    z = r * np.sin(v + poloidal_rot)
    return x, y, z

# Plot the Doughnut with Two Spins
def plot_doughnut(toroidal_rot=0, poloidal_rot=0, spin_x=0, spin_y=0, spin_z=0):
    R, r = 1.0, 0.3  # Major and minor radii
    x, y, z = doughnut_points(R, r, toroidal_rot=toroidal_rot, poloidal_rot=poloidal_rot)
    x, y, z = rotate_doughnut(x, y, z, spin_x, spin_y, spin_z)

    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.0, 1.0])

    # Plot the torus
    ax.plot_surface(x, y, z, color='lightblue', alpha=0.6, edgecolor='gray')

    # Add rotation vectors
    ax.quiver(0, 0, 0, 0, 0, 1, color='red', label=r"$\omega_z$")
    ax.quiver(0, 0, 0, 0, 1, 0, color='green', label=r"$\omega_y$")
    ax.quiver(0, 0, 0, 1, 0, 0, color='blue', label=r"$\omega_x$")
    ax.text(0, 0, 1.2, "Toroidal and Poloidal Rotation", color='purple')

    # Title and legend
    ax.set_title("Rotating Doughnut with Toroidal and Poloidal Motion", fontsize=14)
    ax.legend()
    plt.show()

# Interactive Controls
interact(
    plot_doughnut,
    toroidal_rot=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Toroidal Rot"),
    poloidal_rot=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Poloidal Rot"),
    spin_x=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin X"),
    spin_y=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Y"),
    spin_z=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Z")
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Toroidal Rot', max=6.283185307179586), FloatSlider(v…
# <function __main__.plot_doughnut(toroidal_rot=0, poloidal_rot=0, spin_x=0, spin_y=0, spin_z=0)>

# %%
# Doughnut with a Checkerboard Pattern
def doughnut_checkerboard(R=1.0, r=0.3, n_major=50, n_minor=30, toroidal_rot=0, poloidal_rot=0):
    u = np.linspace(0, 2 * np.pi, n_major)
    v = np.linspace(0, 2 * np.pi, n_minor)
    u, v = np.meshgrid(u, v)

    # Apply toroidal and poloidal rotations
    x = (R + r * np.cos(v + poloidal_rot)) * np.cos(u + toroidal_rot)
    y = (R + r * np.cos(v + poloidal_rot)) * np.sin(u + toroidal_rot)
    z = r * np.sin(v + poloidal_rot)

    # Checkerboard pattern
    colors = (np.sin(2 * u) * np.sin(2 * v)) > 0  # Boolean pattern
    return x, y, z, colors

def plot_doughnut_checkerboard(toroidal_rot=0, poloidal_rot=0, spin_x=0, spin_y=0, spin_z=0):
    R, r = 1.0, 0.3  # Major and minor radii
    x, y, z, colors = doughnut_checkerboard(R, r, toroidal_rot=toroidal_rot, poloidal_rot=poloidal_rot)
    x, y, z = rotate_doughnut(x, y, z, spin_x, spin_y, spin_z)

    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.0, 1.0])

    # Plot the torus with checkerboard pattern
    for i in range(x.shape[0] - 1):
        for j in range(x.shape[1] - 1):
            color = 'white' if colors[i, j] else 'black'
            ax.plot_surface(
                x[i:i+2, j:j+2],
                y[i:i+2, j:j+2],
                z[i:i+2, j:j+2],
                color=color, edgecolor='none'
            )

    # Add rotation vectors
    ax.quiver(0, 0, 0, 0, 0, 1, color='red', label=r"$\omega_z$")
    ax.quiver(0, 0, 0, 0, 1, 0, color='green', label=r"$\omega_y$")
    ax.quiver(0, 0, 0, 1, 0, 0, color='blue', label=r"$\omega_x$")
    ax.text(0, 0, 1.2, "Toroidal and Poloidal Rotation", color='purple')

    # Title and legend
    ax.set_title("Checkerboard Pattern Doughnut", fontsize=14)
    ax.legend()
    plt.show()

# Interactive Controls
interact(
    plot_doughnut_checkerboard,
    toroidal_rot=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Toroidal Rot"),
    poloidal_rot=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Poloidal Rot"),
    spin_x=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin X"),
    spin_y=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Y"),
    spin_z=FloatSlider(min=0, max=2*np.pi, step=0.1, value=0, description="Spin Z")
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Toroidal Rot', max=6.283185307179586), FloatSlider(v…
# <function __main__.plot_doughnut_checkerboard(toroidal_rot=0, poloidal_rot=0, spin_x=0, spin_y=0, spin_z=0)>

# %% [markdown]
# Let’s now dive into studying **boosts and rotations** of the double-spin doughnut ("double dingly donut") systematically and create a table for clarity.
#
# ---
#
# ### Key Considerations
# For our doughnut:
# 1. **Rotations**:
#    - **Toroidal Spin** ($ \omega_{\text{toroidal}} $): Rotation along the major axis.
#    - **Poloidal Spin** ($ \omega_{\text{poloidal}} $): Rotation along the minor axis (cross-section).
#
# 2. **Boosts**:
#    - Linear boosts $ \vec{v} = (v_x, v_y, v_z) $ affect the translational kinetic energy and may interact with angular momentum depending on their alignment with the rotations.
#
# 3. **Quantities to Evaluate**:
#    - **Angular Momentum** ($ \vec{L} $): Affected by both spins.
#    - **Kinetic Energy**:
#      - Rotational $ KE_{\text{rot}} $.
#      - Translational $ KE_{\text{trans}} = \frac{1}{2} M v^2 $.
#      - Total $ KE_{\text{total}} = KE_{\text{rot}} + KE_{\text{trans}} $.
#    - **Symmetries**:
#      - Some combinations of boosts and rotations may produce similar results due to the doughnut's geometry.
#
# ---
#
# ### Table of Scenarios
# We will consider:
# 1. **Spin Configurations**:
#    - Toroidal spin only ($ \omega_{\text{toroidal}} $).
#    - Poloidal spin only ($ \omega_{\text{poloidal}} $).
#    - Both spins combined.
#
# 2. **Boost Directions**:
#    - Along $ x, y, z $-axes.
#
# ### Logic Map
#
# | Toroidal Spin ($ \omega_{\text{toroidal}} $) | Poloidal Spin ($ \omega_{\text{poloidal}} $) | Boost ($ \vec{v} $) | Angular Momentum ($ \vec{L} $)                                         | Kinetic Energy ($ KE_{\text{total}} $)                | Symmetry/Comments                        |
# |-----------------------------------------------|-----------------------------------------------|-----------------------|--------------------------------------------------------------------------|--------------------------------------------------------|-------------------------------------------|
# | Yes                                           | No                                            | $ x $               | $ L_{\text{toroidal}} = I_{\text{toroidal}} \omega_{\text{toroidal}} $ | $ KE_{\text{rot}} + \frac{1}{2} M v_x^2 $            | Translational $ KE $ added independently |
# | Yes                                           | No                                            | $ y $               | Same as above                                                           | Same as above                                           | Similar to $ x $-boost, symmetry        |
# | Yes                                           | No                                            | $ z $               | Same as above                                                           | Same as above                                           | Boost orthogonal to $ \omega_{\text{toroidal}} $     |
# | No                                            | Yes                                           | $ x $               | $ L_{\text{poloidal}} = I_{\text{poloidal}} \omega_{\text{poloidal}} $ | $ KE_{\text{rot}} + \frac{1}{2} M v_x^2 $            | Translational $ KE $ added independently |
# | No                                            | Yes                                           | $ y $               | Same as above                                                           | Same as above                                           | Boost orthogonal to $ \omega_{\text{poloidal}} $     |
# | No                                            | Yes                                           | $ z $               | Same as above                                                           | Same as above                                           | Similar to $ x $-boost, symmetry        |
# | Yes                                           | Yes                                           | $ x $               | $ L = L_{\text{toroidal}} + L_{\text{poloidal}} $                      | $ KE_{\text{rot}} + \frac{1}{2} M v_x^2 $            | Angular momentum contributions combine    |
# | Yes                                           | Yes                                           | $ y $               | Same as above                                                           | Same as above                                           | Boost orthogonal to both spins            |
# | Yes                                           | Yes                                           | $ z $               | Same as above                                                           | Same as above                                           | Boost orthogonal to poloidal, aligns with toroidal |
#
# ---
#
# ### Observations
# 1. **Boosts Along Spin Axes**:
#    - If the boost is aligned with a spin axis, translational and rotational quantities add independently.
#
# 2. **Boosts Orthogonal to Spins**:
#    - For orthogonal boosts, the rotational dynamics remain unchanged, but angular momentum may need to be recomposed in the boosted frame.
#
# 3. **Combined Spins**:
#    - Angular momentum is the sum of contributions from both spins:
#
# $$
# \vec{L} = \vec{L}_{\text{toroidal}} + \vec{L}_{\text{poloidal}}
# $$
#
# 4. **Symmetries**:
#    - The doughnut's geometry ensures some symmetry for boosts along $ x $- and $ y $-axes when either spin is along $ z $, and vice versa.
#
# ---
#
# ### Next Steps
# Would you like:
# 1. A Python simulation to dynamically explore this table?
# 2. More detailed symbolic calculations for angular momentum or kinetic energy?
# 3. Further extensions to asymmetrical cases or relativistic boosts?

# %% [markdown]
# Adding an overall spin to the entire doughnut introduces another layer of complexity. This transforms the problem into a **3D table** because we now have three dimensions of variations:
#
# 1. **Intrinsic Spins**:
#    - **Toroidal Spin** ($ \omega_{\text{toroidal}} $): Rotation along the toroidal axis.
#    - **Poloidal Spin** ($ \omega_{\text{poloidal}} $): Rotation around the toroidal cross-section.
#
# 2. **Overall Spin**:
#    - A spin of the entire doughnut about a global axis ($ \omega_{\text{global}} $).
#
# 3. **Boosts**:
#    - Translational motion $ \vec{v} $ along $ x, y, z $-axes.
#
# This makes the situation far richer, as each combination introduces distinct angular momentum, energy, and symmetry considerations.
#
# ---
#
# ### 3D Logic Map: Scenarios with an Overall Spin
# For clarity, let’s fix the **global spin axis** and study its interactions with intrinsic spins and boosts. We’ll use the $ z $-axis as the global spin axis ($ \omega_{\text{global, z}} $).
#
# ---
#
# #### Expanded Table
#
# | Toroidal Spin ($ \omega_{\text{toroidal}} $) | Poloidal Spin ($ \omega_{\text{poloidal}} $) | Global Spin ($ \omega_{\text{global}} $) | Boost ($ \vec{v} $) | Angular Momentum ($ \vec{L} $)                                                                                     | Kinetic Energy ($ KE_{\text{total}} $)                                                   | Symmetry/Comments                                  |
# |-----------------------------------------------|-----------------------------------------------|--------------------------------------------|-----------------------|------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------|---------------------------------------------------|
# | Yes                                           | No                                            | No                                         | $ x $               | $ L_{\text{toroidal}} = I_{\text{toroidal}} \omega_{\text{toroidal}} $                      | $ KE_{\text{rot}} + \frac{1}{2} M v_x^2 $                                               | Translational $ KE $ added independently        |
# | Yes                                           | No                                            | Yes                                        | $ x $               | $ L = L_{\text{toroidal}} + L_{\text{global}} $, $ L_{\text{global}} = I_z \omega_{\text{global}} $ | Combined rotational and global contributions                                              | Coupled rotations influence $ L $              |
# | Yes                                           | No                                            | Yes                                        | $ z $               | $ L = L_{\text{toroidal}} + L_{\text{global}} $, same $ z $-axis                           | Translational $ KE $ aligns with spin axis                                             | Boost along aligned rotation axes                 |
# | Yes                                           | Yes                                           | Yes                                        | $ x $               | $ L = L_{\text{toroidal}} + L_{\text{poloidal}} + L_{\text{global}} $                       | Combined $ KE_{\text{rot}} + KE_{\text{trans}} $                                        | All rotations contribute                         |
# | No                                            | Yes                                           | Yes                                        | $ y $               | $ L = L_{\text{poloidal}} + L_{\text{global}} $                                            | Translational orthogonal to $ L_{\text{global}} $                                       | Orthogonal interactions                          |
# | Yes                                           | Yes                                           | Yes                                        | $ z $               | $ L = L_{\text{toroidal}} + L_{\text{poloidal}} + L_{\text{global}} $, aligned axes         | Total $ KE_{\text{rot}} + KE_{\text{trans}} $ aligns                                    | Symmetric due to $ z $-alignment               |
# | No                                            | Yes                                           | No                                         | $ x $               | $ L_{\text{poloidal}} = I_{\text{poloidal}} \omega_{\text{poloidal}} $                     | Independent addition of rotational and translational contributions                         | Translational $ KE $ unaffected by symmetry     |
#
# ---
#
# ### Observations
# #### 1. **Global Spin Introduces Coupling**:
# - The global spin contributes an additional angular momentum vector ($ \vec{L}_{\text{global}} $) based on its axis of rotation.
# - This creates complex interactions with the toroidal and poloidal intrinsic spins, especially when the axes are not aligned.
#
# #### 2. **Boost Along Spin Axis**:
# - When the boost is along the same axis as a spin (toroidal, poloidal, or global), the translational and rotational quantities add independently.
#
# #### 3. **Boost Orthogonal to Spins**:
# - Boosts orthogonal to spin axes can create non-trivial cross-terms in angular momentum in the new frame.
#
# #### 4. **Symmetries Simplify Some Cases**:
# - When intrinsic spins are aligned with the global spin, angular momentum and kinetic energy calculations simplify due to shared axes.
#
# ---
#
# ### 3D Table Challenges
# The table becomes exponentially complex as we add:
# 1. Arbitrary orientations for global spins ($ \omega_{\text{global}} $ not limited to $ z $-axis).
# 2. Combined sequential boosts along multiple axes.
#
# ---
#
# ### Simulation Plan
# If you'd like, we can:
# 1. Simulate a 3D table interactively by visualizing:
#    - The doughnut's intrinsic spins (toroidal and poloidal).
#    - The global spin.
#    - The effect of boosts.
# 2. Provide **symbolic forms** for angular momentum and kinetic energy that dynamically update based on the parameters.
# 3. Create visual overlays to depict the combined contributions of spins and boosts.
#
# Would you like to proceed with one of these directions?
